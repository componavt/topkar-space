# %% [markdown]
# <a href="https://colab.research.google.com/github/componavt/topkar-space/blob/main/src%20/ner/distance_based_abbr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def analyze_and_save_simple():
    """
    Упрощенная версия с сохранением результатов
    """
    abbreviations = load_abbreviations('abbreviations.csv')

    # with open('output_line_by_line.txt', 'r', encoding='utf-8') as file:
    #     lines = file.readlines()
    lines = df
    results = []

    for line_num, line in enumerate(lines, 1):
        words = re.findall(r'\b[\w.-]+(?:\.\w*)?\b', line)

        for word in words:
            if word in abbreviations:
                results.append(f"Строка {line_num}: '{word}' -> {abbreviations[word]}\nКонтекст: {line.strip()}\n{'-'*50}")

    # Сохраняем в файл
    with open('res.txt', 'w', encoding='utf-8') as f:
        f.write(f"Найдено сокращений: {len(results)}\n\n")
        f.write("\n".join(results))

    print(f"Результаты сохранены в файл 'найденные_сокращения.txt'")
    print(f"Всего найдено: {len(results)} сокращений")

# Альтернативный запуск
analyze_and_save_simple()
# Out:
# {'бар.': 'барак', 'бер.': 'берег', 'берег': 'берег', 'бол.': 'болото', 'бл.': 'болото', 'бор': 'бор', 'боч.': 'бочага', 'бух.': 'бухта', 'б.': 'бухта', 'варн.': 'варница', 'водоп.': 'водопад', 'вдп.': 'водопад', 'волок': 'волок', 'влк.': 'волок', 'выг.': 'выгон', 'высел.': 'выселок', 'в-лок': 'выселок', 'гмс': 'гидрометеорологическая станция', 'г.': 'город', 'гор.': 'город', 'губ.': 'губа', 'гб.': 'губа', 'гум.': 'гумно', 'д.': 'дом', 'дер.': 'дерево', 'дом': 'дом', 'дор.': 'дорога', 'заводь': 'заводь', 'зак.': 'закол', 'зал.': 'залив', 'з.': 'залив', 'зим.': 'зимник', 'изб.': 'изба', 'изг.': 'изгородь', 'казар.': 'казарма', 'каз.': 'казарма', 'кам.': 'камень', 'к.': 'камень', 'кан.': 'канава', 'кар.': 'карьер', 'клдб.': 'кладбище', 'кл.': 'кладбище', 'колод.': 'колодец', 'клд.': 'колодец', 'кол.': 'колодец', 'кол. пос.': 'колонизационный поселок', 'клх.': 'колхоз', 'колх.': 'колхоз', 'кр.': 'крест', 'куз.': 'кузница', 'лаб.': 'лабиринт', 'лам.': 'ламба', 'л.': 'лес', 'лес': 'лес', 'лес. изб.': 'лесная изба', 'лесоз-д': 'лесозавод', 'лзд.': 'лесозавод', 'лесоп.': 'лесопункт', 'лесоуч.': 'лесоучасток', 'луд.': 'луда', 'луж.': 'лужа', 'м.': 'мыс', 'маяк': 'маяк', 'межа': 'межа', 'мель': 'мель', 'мел.': 'мельница', 'м-ко': 'местечко', 'местн.': 'местность', 'мон.': 'монастырь', 'мор.': 'море', 'мост': 'мост', 'мостки': 'мостки', 'мыс': 'мыс', 'н. п.': 'населённый пункт', 'нива': 'нива', 'низ.': 'низина', 'овр.': 'овраг', 'ов.': 'овраг', 'оз.': 'озеро', 'о.': 'остров', 'омут': 'омут', 'о-в': 'остров', 'остр.': 'остров', 'отм.': 'отмель', 'пастб.': 'пастбище', 'паст.': 'пастбище', 'пер.': 'перекресток', 'перекрест.': 'перекресток', 'переш.': 'перешеек', 'плотин.': 'плотина', 'плт.': 'плотина', 'плс.': 'плёс', 'пов.': 'поворот', 'пож.': 'пожога', 'пок.': 'покос', 'пол.': 'поляна', 'п-ов': 'полуостров', 'полуост.': 'полуостров', 'порог': 'порог', 'пор.': 'порог', 'пос.': 'поселок', 'п.': 'поселок', 'постр.': 'постройка', 'пгт': 'посёлок городского типа', 'прист.': 'пристань', 'пр.': 'пролив', 'прог.': 'прогон', 'прол.': 'пролив', 'прор.': 'прорубь', 'прос.': 'просека', 'прот.': 'протока', 'пруд': 'пруд', 'прд.': 'пруд', 'пуд.': 'пудас', 'разв.': 'развалины', 'рзд.': 'разъезд', 'расщ.': 'расщелина', 'р.': 'ручей', 'рек.': 'река', 'рига': 'рига', 'род.': 'родник', 'рощ.': 'роща', 'руч.': 'ручей', 'рыб. заб.': 'рыбный забор', 'с.': 'село', 'ск.': 'скала', 'скл.': 'склон', 'смолок.': 'смолокурня', 'ст.': 'станция', 'стн.': 'станция', 'тер.': 'территория', 'ток': 'ток', 'тон.': 'тоня', 'тр.': 'тропа', 'уг.': 'угодье', 'ул.': 'улица', 'у.': 'устье', 'уроч.': 'урочище', 'уст.': 'устье', 'уч-к': 'участок', 'уч.': 'участок', 'ущ.': 'ущелье', 'фам.': 'фамилия', 'фарв.': 'фарватер', 'х.': 'хутор', 'хут.': 'хутор', 'церк.': 'церковь', 'час.': 'часовня', 'ч. д.': 'часть деревни', 'ч. м.': 'часть мыса', 'ч. оз.': 'часть озера', 'ч. пос.': 'часть поселения', 'ч. р.': 'часть реки', 'шах.': 'шахта', 'ям.': 'яма'}
# Результаты сохранены в файл 'найденные_сокращения.txt'
# Всего найдено: 0 сокращений

# %%
import pandas as pd

csv_files = [
    #"https://raw.githubusercontent.com/componavt/topkar-space/main/data/abbreviations.csv",
    "https://raw.githubusercontent.com/componavt/topkar-space/main/data/toponims_fix.csv",
]

df = pd.concat([pd.read_csv(url, sep = ';') for url in csv_files], ignore_index=True)
df = df.reset_index()  # make sure indexes pair with number of rows
df.head()

csv_files = [
    "https://raw.githubusercontent.com/componavt/topkar-space/main/data/abbreviations.csv",
]

dd = pd.concat([pd.read_csv(url, sep = ';') for url in csv_files], ignore_index=True)
dd = dd.reset_index()  # make sure indexes pair with number of rows
dd.head()
# Out:
#    index Обозначение   Сокращения
# 0      0       барак         бар.
# 1      1       берег  бер., берег
# 2      2      болото    бол., бл.
# 3      3         бор          бор
# 4      4      бочага         боч.

# %%
def remove_extra_semicolons_total(text, max_semicolons=3):
    """
    Удаляет лишние точки с запятой, чтобы общее количество не превышало max_semicolons
    Сохраняет первые встреченные точки с запятой
    """
    result = []
    count = 0

    for char in text:
        if char == ';':
            if count < max_semicolons:
                result.append(char)
                count += 1
            # else: пропускаем лишнюю точку с запятой
        else:
            result.append(char)

    return ''.join(result)

def process_file_line_by_line(input_file, output_file, max_semicolons=3):
    """
    Обрабатывает файл построчно (полезно для больших файлов)
    """
    try:
        with open(input_file, 'r', encoding='utf-8') as infile, \
             open(output_file, 'w', encoding='utf-8') as outfile:

            for line in infile:
                processed_line = remove_extra_semicolons_total(line, max_semicolons)
                outfile.write(processed_line)

        print(f"Файл успешно обработан построчно!")
        print(f"Результат сохранен в: {output_file}")

    except FileNotFoundError:
        print(f"Ошибка: Файл '{input_file}' не найден!")
    except Exception as e:
        print(f"Произошла ошибка: {e}")

# Пример использования построчной обработки
if __name__ == "__main__":
    input_filename = "toponyms.csv"
    output_filename = "output_line_by_line.txt"

    process_file_line_by_line(input_filename, output_filename)
# Out:
# Файл успешно обработан построчно!
# Результат сохранен в: output_line_by_line.txt

# %%
import csv
import re
from datetime import datetime
import requests
from io import StringIO

def load_file_from_github(filename, max_lines=None):
    """Компактная загрузка файла с GitHub с ограничением строк"""
    url = f"https://raw.githubusercontent.com/componavt/topkar-space/main/data/{filename}"
    response = requests.get(url)
    response.raise_for_status()

    text = response.text
    if max_lines is not None:
        lines = text.split('\n')[:max_lines]
        text = '\n'.join(lines)
        print(f"Загружено первых {max_lines} строк из {filename}")

    return text

def load_abbreviations(csv_filename):
    """
    Загружает сокращения из CSV файла
    """
    abbreviations = {}

    # Загружаем файл с GitHub
    csv_content = load_file_from_github(csv_filename)
    csvfile = StringIO(csv_content)

    reader = csv.DictReader(csvfile, delimiter=';')
    for row in reader:
        full_name = row['Обозначение']
        short_forms_str = row['Сокращения']

        if short_forms_str:
            short_forms = [s.strip() for s in short_forms_str.split(',')]
            for short in short_forms:
                if short:
                    abbreviations[short] = full_name
                    print(f"Добавлено сокращение: '{short}' -> {full_name}")

    print(f"\nЗагружено {len(abbreviations)} сокращений")
    return abbreviations

def analyze_file_with_abbreviations(max_lines=None):
    """
    Функция для детального анализа файла с подсчетом статистики
    """
    # Загружаем сокращения
    abbreviations = load_abbreviations('abbreviations.csv')

    # Загружаем текст для анализа с GitHub
    text = load_file_from_github('toponims_fix.csv', max_lines)

    total_matches = 0
    matches_by_type = {}
    all_matches = []

    # Ищем все возможные сокращения в тексте
    for short_form, full_name in abbreviations.items():
        if '.' in short_form:
            pattern = r'\b' + re.escape(short_form) + r'(?=\s|$|\.|,|;)'
        else:
            pattern = r'\b' + re.escape(short_form) + r'\b'

        matches = re.finditer(pattern, text)

        for match in matches:
            total_matches += 1
            line_num = text[:match.start()].count('\n') + 1

            line_start = text.rfind('\n', 0, match.start()) + 1
            line_end = text.find('\n', match.start())
            if line_end == -1:
                line_end = len(text)
            context = text[line_start:line_end].strip()

            if full_name not in matches_by_type:
                matches_by_type[full_name] = []

            match_info = {
                'line': line_num,
                'word': match.group(),
                'full_name': full_name,
                'context': context
            }

            matches_by_type[full_name].append(match_info)
            all_matches.append(match_info)

    all_matches.sort(key=lambda x: x['line'])
    save_results_to_file(all_matches, matches_by_type, total_matches)

    # Вывод количества найденных аббревиатур
    print(f"\n📊 Всего найдено аббревиатур: {total_matches}")
    print("\n📋 Распределение по типам:")
    for geo_type, matches in sorted(matches_by_type.items(), key=lambda x: len(x[1]), reverse=True):
        print(f"  {geo_type}: {len(matches)}")

    return matches_by_type

def save_results_to_file(all_matches, matches_by_type, total_matches):
    """
    Сохраняет результаты в файл
    """
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f"results_{timestamp}.txt"

    with open(filename, 'w', encoding='utf-8') as f:
        for match in all_matches:
            f.write(f"{match['context']};{match['word']}\n")

    print(f"\n💾 Результаты сохранены в файл: {filename}")


if __name__ == "__main__":
    # Запуск теста
    print("Запуск теста поиска сокращений...")
    print("\n" + "=" * 50 + "\n")

    # Обработать только первые 100 строк
    analyze_file_with_abbreviations(max_lines=100)

    # Или обработать все строки:
    # analyze_file_with_abbreviations()
# Out:
# Запуск теста поиска сокращений...
#
# ==================================================
#
# Добавлено сокращение: 'бар.' -> барак
# Добавлено сокращение: 'бер.' -> берег
# Добавлено сокращение: 'берег' -> берег
# Добавлено сокращение: 'бол.' -> болото
# Добавлено сокращение: 'бл.' -> болото
# Добавлено сокращение: 'бор' -> бор
# Добавлено сокращение: 'боч.' -> бочага
# Добавлено сокращение: 'бух.' -> бухта
# Добавлено сокращение: 'б.' -> бухта
# Добавлено сокращение: 'варн.' -> варница
# Добавлено сокращение: 'водоп.' -> водопад
# Добавлено сокращение: 'вдп.' -> водопад
# Добавлено сокращение: 'волок' -> волок
# Добавлено сокращение: 'влк.' -> волок
# Добавлено сокращение: 'выг.' -> выгон
# Добавлено сокращение: 'высел.' -> выселок
# Добавлено сокращение: 'в-лок' -> выселок
# Добавлено сокращение: 'гмс' -> гидрометеорологическая станция
# Добавлено сокращение: 'г.' -> гора
# Добавлено сокращение: 'гор.' -> гора
# Добавлено сокращение: 'г.' -> город
# Добавлено сокращение: 'гор.' -> город
# Добавлено сокращение: 'губ.' -> губа
# Добавлено сокращение: 'гб.' -> губа
# Добавлено сокращение: 'гум.' -> гумно
# Добавлено сокращение: 'д.' -> деревня
# Добавлено сокращение: 'дер.' -> деревня
# Добавлено сокращение: 'дер.' -> дерево
# Добавлено сокращение: 'д.' -> дом
# Добавлено сокращение: 'дом' -> дом
# Добавлено сокращение: 'дор.' -> дорога
# Добавлено сокращение: 'заводь' -> заводь
# Добавлено сокращение: 'зак.' -> закол
# Добавлено сокращение: 'зал.' -> залив
# Добавлено сокращение: 'з.' -> залив
# Добавлено сокращение: 'зим.' -> зимник
# Добавлено сокращение: 'изб.' -> изба
# Добавлено сокращение: 'изг.' -> изгородь
# Добавлено сокращение: 'казар.' -> казарма
# Добавлено сокращение: 'каз.' -> казарма
# Добавлено сокращение: 'кам.' -> камень
# Добавлено сокращение: 'к.' -> камень
# Добавлено сокращение: 'кан.' -> канава
# Добавлено сокращение: 'кар.' -> карьер
# Добавлено сокращение: 'клдб.' -> кладбище
# Добавлено сокращение: 'кл.' -> кладбище
# Добавлено сокращение: 'колод.' -> колодец
# Добавлено сокращение: 'клд.' -> колодец
# Добавлено сокращение: 'кол.' -> колодец
# Добавлено сокращение: 'кол. пос.' -> колонизационный поселок
# Добавлено сокращение: 'клх.' -> колхоз
# Добавлено сокращение: 'колх.' -> колхоз
# Добавлено сокращение: 'кр.' -> крест
# Добавлено сокращение: 'куз.' -> кузница
# Добавлено сокращение: 'лаб.' -> лабиринт
# Добавлено сокращение: 'лам.' -> ламба
# Добавлено сокращение: 'л.' -> лес
# Добавлено сокращение: 'лес' -> лес
# Добавлено сокращение: 'лес. изб.' -> лесная изба
# Добавлено сокращение: 'лесоз-д' -> лесозавод
# Добавлено сокращение: 'лзд.' -> лесозавод
# Добавлено сокращение: 'лесоп.' -> лесопункт
# Добавлено сокращение: 'лесоуч.' -> лесоучасток
# Добавлено сокращение: 'луд.' -> луда
# Добавлено сокращение: 'луж.' -> лужа
# Добавлено сокращение: 'м.' -> маяк
# Добавлено сокращение: 'маяк' -> маяк
# Добавлено сокращение: 'межа' -> межа
# Добавлено сокращение: 'мель' -> мель
# Добавлено сокращение: 'мел.' -> мельница
# Добавлено сокращение: 'м-ко' -> местечко
# Добавлено сокращение: 'местн.' -> местность
# Добавлено сокращение: 'м.' -> место
# Добавлено сокращение: 'мон.' -> монастырь
# Добавлено сокращение: 'м.' -> море
# Добавлено сокращение: 'мор.' -> море
# Добавлено сокращение: 'м.' -> мост
# Добавлено сокращение: 'мост' -> мост
# Добавлено сокращение: 'мостки' -> мостки
# Добавлено сокращение: 'м.' -> мыс
# Добавлено сокращение: 'мыс' -> мыс
# Добавлено сокращение: 'н. п.' -> населённый пункт
# Добавлено сокращение: 'нива' -> нива
# Добавлено сокращение: 'низ.' -> низина
# Добавлено сокращение: 'овр.' -> овраг
# Добавлено сокращение: 'ов.' -> овраг
# Добавлено сокращение: 'оз.' -> озеро
# Добавлено сокращение: 'о.' -> озеро
# Добавлено сокращение: 'омут' -> омут
# Добавлено сокращение: 'о.' -> остров
# Добавлено сокращение: 'о-в' -> остров
# Добавлено сокращение: 'остр.' -> остров
# Добавлено сокращение: 'отм.' -> отмель
# Добавлено сокращение: 'пастб.' -> пастбище
# Добавлено сокращение: 'паст.' -> пастбище
# Добавлено сокращение: 'пер.' -> перевоз
# Добавлено сокращение: 'перекрест.' -> перекресток
# Добавлено сокращение: 'пер.' -> перекресток
# Добавлено сокращение: 'переш.' -> перешеек
# Добавлено сокращение: 'плотин.' -> плотина
# Добавлено сокращение: 'плт.' -> плотина
# Добавлено сокращение: 'плс.' -> плёс
# Добавлено сокращение: 'пов.' -> поворот
# Добавлено сокращение: 'пож.' -> пожога
# Добавлено сокращение: 'пок.' -> покос
# Добавлено сокращение: 'пол.' -> поле
# Добавлено сокращение: 'п-ов' -> полуостров
# Добавлено сокращение: 'полуост.' -> полуостров
# Добавлено сокращение: 'пол.' -> поляна
# Добавлено сокращение: 'порог' -> порог
# Добавлено сокращение: 'пор.' -> порог
# Добавлено сокращение: 'пос.' -> поселение
# Добавлено сокращение: 'пос.' -> поселок
# Добавлено сокращение: 'п.' -> поселок
# Добавлено сокращение: 'постр.' -> постройка
# Добавлено сокращение: 'пгт' -> посёлок городского типа
# Добавлено сокращение: 'прист.' -> пристань
# Добавлено сокращение: 'пр.' -> пристань
# Добавлено сокращение: 'прог.' -> прогон
# Добавлено сокращение: 'прол.' -> пролив
# Добавлено сокращение: 'пр.' -> пролив
# Добавлено сокращение: 'прор.' -> прорубь
# Добавлено сокращение: 'прос.' -> просека
# Добавлено сокращение: 'прот.' -> протока
# Добавлено сокращение: 'пруд' -> пруд
# Добавлено сокращение: 'прд.' -> пруд
# Добавлено сокращение: 'пуд.' -> пудас
# Добавлено сокращение: 'разв.' -> развалины
# Добавлено сокращение: 'рзд.' -> разъезд
# Добавлено сокращение: 'расщ.' -> расщелина
# Добавлено сокращение: 'р.' -> река
# Добавлено сокращение: 'рек.' -> река
# Добавлено сокращение: 'рига' -> рига
# Добавлено сокращение: 'род.' -> родник
# Добавлено сокращение: 'рощ.' -> роща
# Добавлено сокращение: 'р.' -> ручей
# Добавлено сокращение: 'руч.' -> ручей
# Добавлено сокращение: 'рыб. заб.' -> рыбный забор
# Добавлено сокращение: 'с.' -> село
# Добавлено сокращение: 'с.' -> село
# Добавлено сокращение: 'ск.' -> скала
# Добавлено сокращение: 'скл.' -> склон
# Добавлено сокращение: 'смолок.' -> смолокурня
# Добавлено сокращение: 'ст.' -> станция
# Добавлено сокращение: 'стн.' -> станция
# Добавлено сокращение: 'тер.' -> территория
# Добавлено сокращение: 'ток' -> ток
# Добавлено сокращение: 'тон.' -> тоня
# Добавлено сокращение: 'тр.' -> тропа
# Добавлено сокращение: 'уг.' -> угодье
# Добавлено сокращение: 'ул.' -> улица
# Добавлено сокращение: 'у.' -> улица
# Добавлено сокращение: 'уроч.' -> урочище
# Добавлено сокращение: 'уст.' -> устье
# Добавлено сокращение: 'у.' -> устье
# Добавлено сокращение: 'уч-к' -> участок
# Добавлено сокращение: 'уч.' -> участок
# Добавлено сокращение: 'ущ.' -> ущелье
# Добавлено сокращение: 'фам.' -> фамилия
# Добавлено сокращение: 'фарв.' -> фарватер
# Добавлено сокращение: 'х.' -> хутор
# Добавлено сокращение: 'хут.' -> хутор
# Добавлено сокращение: 'церк.' -> церковь
# Добавлено сокращение: 'час.' -> часовня
# Добавлено сокращение: 'ч. д.' -> часть деревни
# Добавлено сокращение: 'ч. м.' -> часть моря
# Добавлено сокращение: 'ч. м.' -> часть мыса
# Добавлено сокращение: 'ч. оз.' -> часть озера
# Добавлено сокращение: 'ч. пос.' -> часть поселения
# Добавлено сокращение: 'ч. р.' -> часть реки
# Добавлено сокращение: 'шах.' -> шахта
# Добавлено сокращение: 'ям.' -> яма
#
# Загружено 155 сокращений
# Загружено первых 100 строк из toponims_fix.csv
#
# 💾 Результаты сохранены в файл: results_20251110_053316.txt
#
# 📊 Всего найдено аббревиатур: 57
#
# 📋 Распределение по типам:
#   дерево: 24
#   озеро: 11
#   дом: 7
#   ручей: 7
#   мыс: 2
#   болото: 1
#   бор: 1
#   мост: 1
#   мостки: 1
#   нива: 1
#   фамилия: 1

# %%
import pandas as pd

# Чтение файла (предполагается, что разделитель - точка с запятой)
df = pd.read_csv('results.txt', sep=';', header=None,
                 names=['id', 'name_ru', 'name_en', 'description', 'abbreviation'])

# Группировка по id и объединение сокращений
result = df.groupby('id').agg({
    'name_ru': 'first',
    'name_en': 'first',
    'description': 'first',
    'abbreviation': lambda x: ', '.join(x)
}).reset_index()

# Сохранение результата
result.to_csv('combined_result.csv', sep=';', index=False)

print("Результат сохранен в файл 'combined_result.csv'")
print("\nРезультат:")
print(result)
# Out:
# Результат сохранен в файл 'combined_result.csv'
#
# Результат:
#           id             name_ru           name_en  \
# 0          3           Pahag’ärv          pahagärv
# 1          4         Sod’järvt’e         sodjärvte
# 2          5        Piirdoinkodi      piirdoinkodi
# 3          6               Koop’              koop
# 4         10  D’akovans’üudaižed  dakovansüudaižed
# ...      ...                 ...               ...
# 30175  65083             Parikku           parikku
# 30176  65084          Пихтолахта        пихтолахта
# 30177  65085         Piihtilahti       piihtilahti
# 30178  65086             Погойла           погойла
# 30179  65108             Валгала           валгала
#
#                                              description abbreviation
# 0      Маленькое озерко за хутором Poh'd'ad'g', между...          оз.
# 1                      Поляны по дороге в дер. Сидорово.         дер.
# 2                 Дом в дер. Койвусельга, фам. Михайлов.   дер., фам.
# 3      Река Колпь, вытекает из оз. Jokšar'v, течет в ...          оз.
# 4           Покос у мостков через болото ( дер. Slabad).         дер.
# ...                                                  ...          ...
# 30175      урочище, расположенное севернее оз. Нялмозеро          оз.
# 30176  современное урочище на восточном берегу оз. Ня...          оз.
# 30177  современное урочище на восточном берегу оз. Ня...          оз.
# 30178  урочище, расположенное юго-восточнее оз. Тепо,...     оз., оз.
# 30179  Историческое поселение в Островской переваре (...           о.
#
# [30180 rows x 5 columns]

# %%
#!pip install stanza
import stanza

# Загружаем модель для русского языка
stanza.download('ru')  # Загрузите модель, если она еще не загружена
nlp = stanza.Pipeline('ru')

# Пример текста на русском языке
text = "Дом в дер. Койвусельга, фам. Михайлов. ="

# Обрабатываем текст
doc = nlp(text)

# Извлекаем именованные сущности
for sentence in doc.sentences:
    for entity in sentence.ents:
        print(f'Текст: {entity.text}, Тип: {entity.type}')
import stanza

text = "Яблоко рассматривает возможность покупки стартапа в Великобритании за 1 миллиард долларов. Владимир Путин является президентом России. А ещё паста и Кижи"

doc = nlp(text)

for sentence in doc.sentences:
    for entity in sentence.ents:
        print(f'Текст: {entity.text}, Тип: {entity.type}')

import pandas as pd

csv_files = [
#    "https://raw.githubusercontent.com/componavt/topkar-space/main/data/sample10.csv",
    "https://raw.githubusercontent.com/componavt/topkar-space/main/data/toponims_fix.csv",
]

df = pd.concat([pd.read_csv(url, sep = ';') for url in csv_files], ignore_index=True)
df = df.reset_index()  # make sure indexes pair with number of rows
df.head()
# Out:
# Collecting stanza
#   Downloading stanza-1.11.0-py3-none-any.whl.metadata (14 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (5.29.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza) (3.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->stanza) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->stanza) (3.0.3)
# Downloading stanza-1.11.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.7 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 42.1 MB/s eta 0:00:00
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.15.0 stanza-1.11.0
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: ru (Russian) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.11.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/ru/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# | ner       | wikiner            |
# ==================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# Текст: Михайлов, Тип: LOC
# Текст: Великобритании, Тип: LOC
# Текст: Владимир Путин, Тип: PER
# Текст: России, Тип: LOC
# Текст: Кижи, Тип: LOC
#    index  id               name            synonym  \
# 0      0   1  Наволоцкая поляна  наволоцкая поляна
# 1      1   2    Галайские пожни    галайские пожни
# 2      2   3          Pahag’ärv           pahagärv
# 3      3   4        Sod’järvt’e          sodjärvte
# 4      4   5       Piirdoinkodi       piirdoinkodi
#
#                                            main_text
# 0                Пахотная поляна в устье Пижейручья.
# 1  покосы на юге острова Галайский, см. Галайский...
# 2  Маленькое озерко за хутором Poh'd'ad'g', между...
# 3                  Поляны по дороге в дер. Сидорово.
# 4             Дом в дер. Койвусельга, фам. Михайлов.

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
import re
import csv
from ast import Import
import nltk
import re
import time
from datetime import timedelta
from nltk.tokenize import sent_tokenize, word_tokenize

# Функция для загрузки сокращений из CSV файла
def load_abbreviations(csv_filename):
    """
    Загружает сокращения из CSV файла
    """
    print(f"⏳ Загрузка сокращений из {csv_filename}...")
    start_time = time.time()

    abbreviations = {}
    try:
        with open(csv_filename, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile, delimiter=';')
            for row in reader:
                full_name = row['Обозначение']
                short_forms_str = row['Сокращения']

                if short_forms_str:
                    # Разделяем по запятой и убираем пробелы
                    short_forms = [s.strip() for s in short_forms_str.split(',')]

                    for short in short_forms:
                        if short:
                            abbreviations[short] = full_name
                            print(f"Добавлено сокращение: '{short}' -> {full_name}")
    except Exception as e:
        print(f"Error loading abbreviations: {e}")
        # Альтернативный способ чтения если структура файла отличается
        try:
            with open(csv_filename, 'r', encoding='utf-8') as f:
                lines = f.readlines()
                for line in lines:
                    if ';' in line:
                        parts = line.strip().split(';')
                        if len(parts) >= 2:
                            full_name = parts[0].strip()
                            short_forms_str = parts[1].strip()
                            short_forms = [s.strip() for s in short_forms_str.split(',')]
                            for short in short_forms:
                                if short:
                                    abbreviations[short] = full_name
        except Exception as e2:
            print(f"Alternative loading also failed: {e2}")

    load_time = time.time() - start_time
    print(f" Загружено {len(abbreviations)} сокращений за {load_time:.2f} секунд")
    return abbreviations

# Функция для создания паттернов регулярных выражений
def create_abbreviation_patterns(abbreviations_dict):
    """
    Создает паттерны регулярных выражений для всех сокращений
    """
    print(f"🔧 Создание паттернов для {len(abbreviations_dict)} сокращений...")
    patterns = {}

    for short_form, full_name in abbreviations_dict.items():
        if '.' in short_form:
            # Для сокращений с точкой: ищем с точкой, после которой может быть пробел или конец строки
            pattern = r'\b' + re.escape(short_form) + r'(?=\s|$|\.|,|;)'
        else:
            # Для сокращений без точки: обычный поиск с границами слов
            pattern = r'\b' + re.escape(short_form) + r'\b'
        patterns[short_form] = (pattern, full_name)

    print(f" Паттерны созданы для {len(patterns)} сокращений")
    return patterns

# Функция для поиска сокращений в окрестности топонима
def find_nearby_abbreviations(text, toponym, patterns, distance_words=2):
    """
    Ищет сокращения в окрестности топонима используя предварительно созданные паттерны
    """
    search_start_time = time.time()
    nearby_abbreviations = []

    # Находим все вхождения топонима в тексте
    toponym_search_start = time.time()
    toponym_pattern = re.escape(toponym)
    toponym_matches = list(re.finditer(toponym_pattern, text))
    toponym_search_time = time.time() - toponym_search_start
    print(f"    Поиск топонима '{toponym}': {toponym_search_time:.4f} сек, найдено {len(toponym_matches)} вхождений")

    for toponym_match in toponym_matches:
        toponym_start = toponym_match.start()
        toponym_end = toponym_match.end()

        # Определяем окрестность вокруг топонима (в символах)
        # Приблизительно: считаем что в среднем слово = 6 символов + пробел
        approx_distance_chars = distance_words * 7

        search_start = max(0, toponym_start - approx_distance_chars)
        search_end = min(len(text), toponym_end + approx_distance_chars)

        search_area = text[search_start:search_end]

        # Ищем все сокращения в этой области
        abbreviation_search_start = time.time()
        for short_form, (pattern, full_name) in patterns.items():
            abbreviation_matches = list(re.finditer(pattern, search_area))

            for abbr_match in abbreviation_matches:
                # Вычисляем абсолютную позицию сокращения в тексте
                abbr_absolute_pos = search_start + abbr_match.start()

                # Проверяем что сокращение не является частью самого топонима
                if not (toponym_start <= abbr_absolute_pos <= toponym_end):
                    abbr_info = {
                        'abbreviation': abbr_match.group(),
                        'full_name': full_name,
                        'position': abbr_absolute_pos,
                        'context': search_area
                    }

                    # Проверяем на дубликаты
                    is_duplicate = False
                    for existing in nearby_abbreviations:
                        if (existing['abbreviation'] == abbr_info['abbreviation'] and
                            existing['full_name'] == abbr_info['full_name'] and
                            abs(existing['position'] - abbr_info['position']) < 10):
                            is_duplicate = True
                            break

                    if not is_duplicate:
                        nearby_abbreviations.append(abbr_info)

        abbreviation_search_time = time.time() - abbreviation_search_start
        print(f"    Поиск сокращений вокруг '{toponym}': {abbreviation_search_time:.4f} сек")

    total_search_time = time.time() - search_start_time
    if nearby_abbreviations:
        print(f"    Найдено {len(nearby_abbreviations)} сокращений за {total_search_time:.4f} сек")
    else:
        print(f"    Сокращения не найдены за {total_search_time:.4f} сек")

    return nearby_abbreviations

# Основной код
def main(max_lines=None):
    """
    Основная функция с ограничением количества строк

    Args:
        max_lines (int): Максимальное количество строк для обработки. Если None - обрабатывает все.
    """
    total_start_time = time.time()
    max_lines = 100
    # Загружаем сокращения
    abbreviations_dict = load_abbreviations('abbreviations.csv')

    # Создаем паттерны регулярных выражений один раз для всех вызовов
    patterns_creation_start = time.time()
    patterns = create_abbreviation_patterns(abbreviations_dict)
    patterns_creation_time = time.time() - patterns_creation_start
    print(f"⏱ Общее время создания паттернов: {patterns_creation_time:.4f} сек")

    lines = df['main_text'].tolist()
    print(f"\n Всего предложений в данных: {len(lines)}")

    # Применяем ограничение по количеству строк
    if max_lines is not None:
        lines = lines[:max_lines]
        print(f" Обрабатывается только первых {max_lines} строк")

    df['main_text'] = df['main_text'].replace({float('nan'): ""})
    num = 0
    output_csv = 'output.csv'

    # Статистика
    total_toponyms = 0
    total_abbreviations = 0
    processed_sentences = 0

    # Время для статистики
    total_toponym_time = 0
    total_abbreviation_time = 0
    total_nlp_time = 0

    print(f"\n Начало обработки {len(lines)} предложений...")
    processing_start_time = time.time()

    with open(output_csv, 'w', encoding='utf-8') as outfile:
        outfile.writelines(f"sentence_id; toponyms_list; nearby_abbreviations \n")

        for sentence in lines:
            if pd.isna(sentence) or sentence == "":
                num += 1
                continue

            sentence_start_time = time.time()

            print(f'\n--- Предложение {num} ---')
            print(f'Текст: {sentence[:100]}...' if len(sentence) > 100 else f'Текст: {sentence}')

            sentence_toponyms = []
            all_nearby_abbreviations = []

            # Находим все топонимы в предложении с таймером
            nlp_start_time = time.time()
            tex = nlp(sentence)
            nlp_time = time.time() - nlp_start_time
            total_nlp_time += nlp_time
            print(f"⏱ Время NLP обработки: {nlp_time:.4f} сек")

            # Поиск топонимов с таймером
            toponym_search_start = time.time()
            for entity in tex.ents:
                if entity.type == "LOC":
                    entity_find_time = time.time() - toponym_search_start
                    print(f'📍 Топоним: {entity.text} (найден за {entity_find_time:.4f} сек)')
                    sentence_toponyms.append(entity.text)
                    total_toponyms += 1

                    # Обновляем время для следующего топонима
                    toponym_search_start = time.time()

                    # Ищем сокращения в окрестности этого топонима с таймером
                    # Теперь передаем предварительно созданные patterns вместо abbreviations_dict
                    abbreviation_search_start = time.time()
                    nearby_abbr = find_nearby_abbreviations(
                        sentence,
                        entity.text,
                        patterns,  # Передаем готовые паттерны вместо словаря
                        distance_words=5
                    )
                    abbreviation_time = time.time() - abbreviation_search_start
                    total_abbreviation_time += abbreviation_time

                    print(f"    Общее время поиска сокращений для '{entity.text}': {abbreviation_time:.4f} сек")

                    for abbr_info in nearby_abbr:
                        match_str = f"{abbr_info['abbreviation']}"
                        if match_str not in all_nearby_abbreviations:
                            all_nearby_abbreviations.append(match_str)
                            total_abbreviations += 1
                            print(f"    Найдено сокращение: '{abbr_info['abbreviation']}' -> '{abbr_info['full_name']}'")

            # Если не было найдено топонимов, выводим время поиска
            if not sentence_toponyms:
                toponym_time = time.time() - toponym_search_start
                total_toponym_time += toponym_time
                print(f" Время поиска топонимов: {toponym_time:.4f} сек (не найдено)")

            # Формируем строку для вывода
            toponyms_str = ', '.join(sentence_toponyms)
            abbreviations_str = ', '.join(all_nearby_abbreviations)

            strk = f"{num}; {toponyms_str}; {abbreviations_str} \n"
            outfile.writelines(strk)

            sentence_time = time.time() - sentence_start_time
            print(f" Общее время обработки предложения: {sentence_time:.2f} сек")

            processed_sentences += 1
            num += 1

            # Прогресс каждые 10 предложений
            if processed_sentences % 10 == 0:
                elapsed = time.time() - processing_start_time
                print(f"\n Прогресс: обработано {processed_sentences}/{len(lines)} предложений")
                print(f" Прошло времени: {timedelta(seconds=int(elapsed))}")

                # Среднее время по этапам
                if processed_sentences > 0:
                    avg_nlp_time = total_nlp_time / processed_sentences
                    if total_toponyms > 0:
                        avg_abbr_time = total_abbreviation_time / total_toponyms
                        print(f" Среднее время поиска сокращений на топоним: {avg_abbr_time:.4f} сек")

                    print(f" Среднее время NLP: {avg_nlp_time:.4f} сек")

                    avg_time = elapsed / processed_sentences
                    remaining = (len(lines) - processed_sentences) * avg_time
                    print(f" Оставшееся время: ~{timedelta(seconds=int(remaining))}")

    total_time = time.time() - total_start_time

    # Финальная статистика с детализацией по времени
    print(f"\n ОБРАБОТКА ЗАВЕРШЕНА!")
    print(f" Статистика:")
    print(f"   - Обработано предложений: {processed_sentences}")
    print(f"   - Найдено топонимов: {total_toponyms}")
    print(f"   - Найдено сокращений: {total_abbreviations}")
    print(f"   - Общее время: {timedelta(seconds=int(total_time))}")

    if processed_sentences > 0:
        print(f"\n⏱ Детализация времени:")
        print(f"   - Среднее время на предложение: {total_time/processed_sentences:.2f} сек")
        print(f"   - Общее время NLP: {timedelta(seconds=int(total_nlp_time))}")
        print(f"   - Среднее время NLP на предложение: {total_nlp_time/processed_sentences:.4f} сек")
        print(f"   - Время создания паттернов: {patterns_creation_time:.4f} сек")

        if total_toponyms > 0:
            print(f"   - Среднее время поиска сокращений на топоним: {total_abbreviation_time/total_toponyms:.4f} сек")
            print(f"   - Среднее количество топонимов на предложение: {total_toponyms/processed_sentences:.2f}")
            print(f"   - Среднее количество сокращений на топоним: {total_abbreviations/max(total_toponyms, 1):.2f}")

    print(f"   - Результаты сохранены в: {output_csv}")

# Альтернативная версия с более точным поиском по словам
def find_nearby_abbreviations_advanced(text, toponym, patterns, distance_words=5):
    """
    Улучшенная версия поиска с учетом расстояния в словах
    """
    search_start_time = time.time()
    nearby_abbreviations = []

    # Токенизируем текст с сохранением позиций
    tokenization_start = time.time()
    words_with_positions = []
    pattern = r'\b\w+(?:\.\w+)*\b|[^\w\s]'
    for match in re.finditer(pattern, text):
        word = match.group()
        if word.strip():  # Игнорируем чистые пробелы
            words_with_positions.append({
                'word': word,
                'start': match.start(),
                'end': match.end()
            })
    tokenization_time = time.time() - tokenization_start
    print(f"    Токенизация текста: {tokenization_time:.4f} сек")

    # Находим позиции топонима
    toponym_search_start = time.time()
    toponym_positions = []
    for i, word_info in enumerate(words_with_positions):
        # Проверяем отдельные слова и комбинации слов для топонима
        if word_info['word'] in toponym:
            # Простая проверка - можно улучшить для многословных топонимов
            toponym_positions.append(i)
    toponym_search_time = time.time() - toponym_search_start
    print(f"    Поиск позиций топонима: {toponym_search_time:.4f} сек, найдено {len(toponym_positions)} позиций")

    # Для каждой позиции топонима ищем соседние сокращения
    abbreviation_search_start = time.time()
    for pos in toponym_positions:
        start_idx = max(0, pos - distance_words)
        end_idx = min(len(words_with_positions), pos + distance_words + 1)

        for i in range(start_idx, end_idx):
            word_info = words_with_positions[i]
            word = word_info['word']

            # Проверяем является ли слово сокращением
            for short_form, (pattern, full_name) in patterns.items():
                # Сравниваем с очищенной версией сокращения
                clean_short = short_form.replace('.', '')
                clean_word = word.replace('.', '')

                if clean_word == clean_short:
                    abbr_info = {
                        'abbreviation': word,
                        'full_name': full_name,
                        'position': word_info['start']
                    }

                    # Проверяем на дубликаты
                    is_duplicate = False
                    for existing in nearby_abbreviations:
                        if (existing['abbreviation'] == abbr_info['abbreviation'] and
                            existing['full_name'] == abbr_info['full_name']):
                            is_duplicate = True
                            break

                    if not is_duplicate:
                        nearby_abbreviations.append(abbr_info)

    abbreviation_search_time = time.time() - abbreviation_search_start
    total_search_time = time.time() - search_start_time

    print(f"    Поиск сокращений: {abbreviation_search_time:.4f} сек")
    if nearby_abbreviations:
        print(f"    Расширенный поиск: найдено {len(nearby_abbreviations)} сокращений за {total_search_time:.4f} сек")
    else:
        print(f"    Расширенный поиск: сокращения не найдены за {total_search_time:.4f} сек")

    return nearby_abbreviations

# Запуск основной функции
if __name__ == "__main__":
    # Обработать только первые 50 строк для тестирования
    main(max_lines=100)

    # Или обработать все строки:
    # main()
# Out:
# ⏳ Загрузка сокращений из abbreviations.csv...
# Добавлено сокращение: 'бар.' -> барак
# Добавлено сокращение: 'бер.' -> берег
# Добавлено сокращение: 'берег' -> берег
# Добавлено сокращение: 'бол.' -> болото
# Добавлено сокращение: 'бл.' -> болото
# Добавлено сокращение: 'бор' -> бор
# Добавлено сокращение: 'боч.' -> бочага
# Добавлено сокращение: 'бух.' -> бухта
# Добавлено сокращение: 'б.' -> бухта
# Добавлено сокращение: 'варн.' -> варница
# Добавлено сокращение: 'водоп.' -> водопад
# Добавлено сокращение: 'вдп.' -> водопад
# Добавлено сокращение: 'волок' -> волок
# Добавлено сокращение: 'влк.' -> волок
# Добавлено сокращение: 'выг.' -> выгон
# Добавлено сокращение: 'высел.' -> выселок
# Добавлено сокращение: 'в-лок' -> выселок
# Добавлено сокращение: 'гмс' -> гидрометеорологическая станция
# Добавлено сокращение: 'г.' -> гора
# Добавлено сокращение: 'гор.' -> гора
# Добавлено сокращение: 'г.' -> город
# Добавлено сокращение: 'гор.' -> город
# Добавлено сокращение: 'губ.' -> губа
# Добавлено сокращение: 'гб.' -> губа
# Добавлено сокращение: 'гум.' -> гумно
# Добавлено сокращение: 'д.' -> деревня
# Добавлено сокращение: 'дер.' -> деревня
# Добавлено сокращение: 'дер.' -> дерево
# Добавлено сокращение: 'д.' -> дом
# Добавлено сокращение: 'дом' -> дом
# Добавлено сокращение: 'дор.' -> дорога
# Добавлено сокращение: 'заводь' -> заводь
# Добавлено сокращение: 'зак.' -> закол
# Добавлено сокращение: 'зал.' -> залив
# Добавлено сокращение: 'з.' -> залив
# Добавлено сокращение: 'зим.' -> зимник
# Добавлено сокращение: 'изб.' -> изба
# Добавлено сокращение: 'изг.' -> изгородь
# Добавлено сокращение: 'казар.' -> казарма
# Добавлено сокращение: 'каз.' -> казарма
# Добавлено сокращение: 'кам.' -> камень
# Добавлено сокращение: 'к.' -> камень
# Добавлено сокращение: 'кан.' -> канава
# Добавлено сокращение: 'кар.' -> карьер
# Добавлено сокращение: 'клдб.' -> кладбище
# Добавлено сокращение: 'кл.' -> кладбище
# Добавлено сокращение: 'колод.' -> колодец
# Добавлено сокращение: 'клд.' -> колодец
# Добавлено сокращение: 'кол.' -> колодец
# Добавлено сокращение: 'кол. пос.' -> колонизационный поселок
# Добавлено сокращение: 'клх.' -> колхоз
# Добавлено сокращение: 'колх.' -> колхоз
# Добавлено сокращение: 'кр.' -> крест
# Добавлено сокращение: 'куз.' -> кузница
# Добавлено сокращение: 'лаб.' -> лабиринт
# Добавлено сокращение: 'лам.' -> ламба
# Добавлено сокращение: 'л.' -> лес
# Добавлено сокращение: 'лес' -> лес
# Добавлено сокращение: 'лес. изб.' -> лесная изба
# Добавлено сокращение: 'лесоз-д' -> лесозавод
# Добавлено сокращение: 'лзд.' -> лесозавод
# Добавлено сокращение: 'лесоп.' -> лесопункт
# Добавлено сокращение: 'лесоуч.' -> лесоучасток
# Добавлено сокращение: 'луд.' -> луда
# Добавлено сокращение: 'луж.' -> лужа
# Добавлено сокращение: 'м.' -> маяк
# Добавлено сокращение: 'маяк' -> маяк
# Добавлено сокращение: 'межа' -> межа
# Добавлено сокращение: 'мель' -> мель
# Добавлено сокращение: 'мел.' -> мельница
# Добавлено сокращение: 'м-ко' -> местечко
# Добавлено сокращение: 'местн.' -> местность
# Добавлено сокращение: 'м.' -> место
# Добавлено сокращение: 'мон.' -> монастырь
# Добавлено сокращение: 'м.' -> море
# Добавлено сокращение: 'мор.' -> море
# Добавлено сокращение: 'м.' -> мост
# Добавлено сокращение: 'мост' -> мост
# Добавлено сокращение: 'мостки' -> мостки
# Добавлено сокращение: 'м.' -> мыс
# Добавлено сокращение: 'мыс' -> мыс
# Добавлено сокращение: 'н. п.' -> населённый пункт
# Добавлено сокращение: 'нива' -> нива
# Добавлено сокращение: 'низ.' -> низина
# Добавлено сокращение: 'овр.' -> овраг
# Добавлено сокращение: 'ов.' -> овраг
# Добавлено сокращение: 'оз.' -> озеро
# Добавлено сокращение: 'о.' -> озеро
# Добавлено сокращение: 'омут' -> омут
# Добавлено сокращение: 'о.' -> остров
# Добавлено сокращение: 'о-в' -> остров
# Добавлено сокращение: 'остр.' -> остров
# Добавлено сокращение: 'отм.' -> отмель
# Добавлено сокращение: 'пастб.' -> пастбище
# Добавлено сокращение: 'паст.' -> пастбище
# Добавлено сокращение: 'пер.' -> перевоз
# Добавлено сокращение: 'перекрест.' -> перекресток
# Добавлено сокращение: 'пер.' -> перекресток
# Добавлено сокращение: 'переш.' -> перешеек
# Добавлено сокращение: 'плотин.' -> плотина
# Добавлено сокращение: 'плт.' -> плотина
# Добавлено сокращение: 'плс.' -> плёс
# Добавлено сокращение: 'пов.' -> поворот
# Добавлено сокращение: 'пож.' -> пожога
# Добавлено сокращение: 'пок.' -> покос
# Добавлено сокращение: 'пол.' -> поле
# Добавлено сокращение: 'п-ов' -> полуостров
# Добавлено сокращение: 'полуост.' -> полуостров
# Добавлено сокращение: 'пол.' -> поляна
# Добавлено сокращение: 'порог' -> порог
# Добавлено сокращение: 'пор.' -> порог
# Добавлено сокращение: 'пос.' -> поселение
# Добавлено сокращение: 'пос.' -> поселок
# Добавлено сокращение: 'п.' -> поселок
# Добавлено сокращение: 'постр.' -> постройка
# Добавлено сокращение: 'пгт' -> посёлок городского типа
# Добавлено сокращение: 'прист.' -> пристань
# Добавлено сокращение: 'пр.' -> пристань
# Добавлено сокращение: 'прог.' -> прогон
# Добавлено сокращение: 'прол.' -> пролив
# Добавлено сокращение: 'пр.' -> пролив
# Добавлено сокращение: 'прор.' -> прорубь
# Добавлено сокращение: 'прос.' -> просека
# Добавлено сокращение: 'прот.' -> протока
# Добавлено сокращение: 'пруд' -> пруд
# Добавлено сокращение: 'прд.' -> пруд
# Добавлено сокращение: 'пуд.' -> пудас
# Добавлено сокращение: 'разв.' -> развалины
# Добавлено сокращение: 'рзд.' -> разъезд
# Добавлено сокращение: 'расщ.' -> расщелина
# Добавлено сокращение: 'р.' -> река
# Добавлено сокращение: 'рек.' -> река
# Добавлено сокращение: 'рига' -> рига
# Добавлено сокращение: 'род.' -> родник
# Добавлено сокращение: 'рощ.' -> роща
# Добавлено сокращение: 'р.' -> ручей
# Добавлено сокращение: 'руч.' -> ручей
# Добавлено сокращение: 'рыб. заб.' -> рыбный забор
# Добавлено сокращение: 'с.' -> село
# Добавлено сокращение: 'с.' -> село
# Добавлено сокращение: 'ск.' -> скала
# Добавлено сокращение: 'скл.' -> склон
# Добавлено сокращение: 'смолок.' -> смолокурня
# Добавлено сокращение: 'ст.' -> станция
# Добавлено сокращение: 'стн.' -> станция
# Добавлено сокращение: 'тер.' -> территория
# Добавлено сокращение: 'ток' -> ток
# Добавлено сокращение: 'тон.' -> тоня
# Добавлено сокращение: 'тр.' -> тропа
# Добавлено сокращение: 'уг.' -> угодье
# Добавлено сокращение: 'ул.' -> улица
# Добавлено сокращение: 'у.' -> улица
# Добавлено сокращение: 'уроч.' -> урочище
# Добавлено сокращение: 'уст.' -> устье
# Добавлено сокращение: 'у.' -> устье
# Добавлено сокращение: 'уч-к' -> участок
# Добавлено сокращение: 'уч.' -> участок
# Добавлено сокращение: 'ущ.' -> ущелье
# Добавлено сокращение: 'фам.' -> фамилия
# Добавлено сокращение: 'фарв.' -> фарватер
# Добавлено сокращение: 'х.' -> хутор
# Добавлено сокращение: 'хут.' -> хутор
# Добавлено сокращение: 'церк.' -> церковь
# Добавлено сокращение: 'час.' -> часовня
# Добавлено сокращение: 'ч. д.' -> часть деревни
# Добавлено сокращение: 'ч. м.' -> часть моря
# Добавлено сокращение: 'ч. м.' -> часть мыса
# Добавлено сокращение: 'ч. оз.' -> часть озера
# Добавлено сокращение: 'ч. пос.' -> часть поселения
# Добавлено сокращение: 'ч. р.' -> часть реки
# Добавлено сокращение: 'шах.' -> шахта
# Добавлено сокращение: 'ям.' -> яма
#  Загружено 155 сокращений за 0.00 секунд
# 🔧 Создание паттернов для 155 сокращений...
#  Паттерны созданы для 155 сокращений
# ⏱ Общее время создания паттернов: 0.0003 сек
#
#  Всего предложений в данных: 53089
#  Обрабатывается только первых 100 строк
#
#  Начало обработки 100 предложений...
#
# --- Предложение 0 ---
# Текст: Пахотная поляна в устье Пижейручья.
# ⏱ Время NLP обработки: 0.7682 сек
# 📍 Топоним: Пижейручья (найден за 0.0000 сек)
#     Поиск топонима 'Пижейручья': 0.0003 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пижейручья': 0.0024 сек
#     Сокращения не найдены за 0.0028 сек
#     Общее время поиска сокращений для 'Пижейручья': 0.0028 сек
#  Общее время обработки предложения: 0.77 сек
#
# --- Предложение 1 ---
# Текст: покосы на юге острова Галайский, см. Галайский Остров
# ⏱ Время NLP обработки: 0.5283 сек
# 📍 Топоним: Галайский (найден за 0.0000 сек)
#     Поиск топонима 'Галайский': 0.0001 сек, найдено 2 вхождений
#     Поиск сокращений вокруг 'Галайский': 0.0004 сек
#     Поиск сокращений вокруг 'Галайский': 0.0004 сек
#     Сокращения не найдены за 0.0010 сек
#     Общее время поиска сокращений для 'Галайский': 0.0010 сек
# 📍 Топоним: Галайский Остров (найден за 0.0010 сек)
#     Поиск топонима 'Галайский Остров': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Галайский Остров': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Галайский Остров': 0.0005 сек
#  Общее время обработки предложения: 0.53 сек
#
# --- Предложение 2 ---
# Текст: Маленькое озерко за хутором Poh'd'ad'g', между оз. Sar'gär'v и Vougedg'är'v.
# ⏱ Время NLP обработки: 0.7091 сек
# 📍 Топоним: Poh'd'ad'g' (найден за 0.0000 сек)
#     Поиск топонима 'Poh'd'ad'g'': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Poh'd'ad'g'': 0.0006 сек
#     Найдено 1 сокращений за 0.0007 сек
#     Общее время поиска сокращений для 'Poh'd'ad'g'': 0.0008 сек
#     Найдено сокращение: 'оз.' -> 'озеро'
# 📍 Топоним: Sar'gär'v (найден за 0.0008 сек)
#     Поиск топонима 'Sar'gär'v': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Sar'gär'v': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Sar'gär'v': 0.0004 сек
# 📍 Топоним: Vougedg'är'v (найден за 0.0004 сек)
#     Поиск топонима 'Vougedg'är'v': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Vougedg'är'v': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Vougedg'är'v': 0.0004 сек
#  Общее время обработки предложения: 0.71 сек
#
# --- Предложение 3 ---
# Текст: Поляны по дороге в дер. Сидорово.
# ⏱ Время NLP обработки: 0.4203 сек
# 📍 Топоним: Поляны (найден за 0.0000 сек)
#     Поиск топонима 'Поляны': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Поляны': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Поляны': 0.0005 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
# 📍 Топоним: Сидорово (найден за 0.0005 сек)
#     Поиск топонима 'Сидорово': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сидорово': 0.0003 сек
#     Найдено 1 сокращений за 0.0003 сек
#     Общее время поиска сокращений для 'Сидорово': 0.0003 сек
#  Общее время обработки предложения: 0.42 сек
#
# --- Предложение 4 ---
# Текст: Дом в дер. Койвусельга, фам. Михайлов.
# ⏱ Время NLP обработки: 0.4627 сек
# 📍 Топоним: Михайлов (найден за 0.0000 сек)
#     Поиск топонима 'Михайлов': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Михайлов': 0.0004 сек
#     Найдено 2 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Михайлов': 0.0005 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#     Найдено сокращение: 'фам.' -> 'фамилия'
#  Общее время обработки предложения: 0.46 сек
#
# --- Предложение 5 ---
# Текст: Река Колпь, вытекает из оз. Jokšar'v, течет в Вологодск. обл.
# ⏱ Время NLP обработки: 0.6393 сек
# 📍 Топоним: Колпь (найден за 0.0000 сек)
#     Поиск топонима 'Колпь': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Колпь': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Колпь': 0.0005 сек
#     Найдено сокращение: 'оз.' -> 'озеро'
# 📍 Топоним: Jokšar'v (найден за 0.0005 сек)
#     Поиск топонима 'Jokšar'v': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Jokšar'v': 0.0005 сек
#     Найдено 1 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Jokšar'v': 0.0006 сек
# 📍 Топоним: Вологодск (найден за 0.0006 сек)
#     Поиск топонима 'Вологодск': 0.0002 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вологодск': 0.0004 сек
#     Найдено 1 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Вологодск': 0.0006 сек
#  Общее время обработки предложения: 0.64 сек
#
# --- Предложение 6 ---
# Текст: Поле находится в 600-700 м на востоке д.Каскосельга.
# ⏱ Время NLP обработки: 0.7174 сек
# 📍 Топоним: Каскосельга (найден за 0.0000 сек)
#     Поиск топонима 'Каскосельга': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Каскосельга': 0.0008 сек
#     Сокращения не найдены за 0.0010 сек
#     Общее время поиска сокращений для 'Каскосельга': 0.0010 сек
#  Общее время обработки предложения: 0.72 сек
#
# --- Предложение 7 ---
# Текст: Урочище, в котором , по сведениям информатора, в 30-х годах упала сосна. Тут болото.
# ⏱ Время NLP обработки: 1.1866 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 1.19 сек
#
# --- Предложение 8 ---
# Текст: Покос у мостков через болото ( дер. Slabad).
# ⏱ Время NLP обработки: 0.7103 сек
# 📍 Топоним: Slabad (найден за 0.0000 сек)
#     Поиск топонима 'Slabad': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Slabad': 0.0007 сек
#     Найдено 1 сокращений за 0.0009 сек
#     Общее время поиска сокращений для 'Slabad': 0.0009 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.71 сек
#
# --- Предложение 9 ---
# Текст: Гора у оз. Čern'eckiig'är'f, за дер. Селище.
# ⏱ Время NLP обработки: 0.5053 сек
# 📍 Топоним: Селище (найден за 0.0000 сек)
#     Поиск топонима 'Селище': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Селище': 0.0004 сек
#     Найдено 2 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Селище': 0.0006 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#     Найдено сокращение: 'оз.' -> 'озеро'
#  Общее время обработки предложения: 0.51 сек
#
#  Прогресс: обработано 10/100 предложений
#  Прошло времени: 0:00:06
#  Среднее время поиска сокращений на топоним: 0.0008 сек
#  Среднее время NLP: 0.6648 сек
#  Оставшееся время: ~0:00:59
#
# --- Предложение 10 ---
# Текст: Озерко за р. Ивадой, у бол. Levahtso.
# ⏱ Время NLP обработки: 0.4193 сек
# 📍 Топоним: Ивадой (найден за 0.0000 сек)
#     Поиск топонима 'Ивадой': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Ивадой': 0.0004 сек
#     Найдено 2 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Ивадой': 0.0005 сек
#     Найдено сокращение: 'бол.' -> 'болото'
#     Найдено сокращение: 'р.' -> 'ручей'
# 📍 Топоним: Levahtso (найден за 0.0006 сек)
#     Поиск топонима 'Levahtso': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Levahtso': 0.0003 сек
#     Найдено 2 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Levahtso': 0.0004 сек
#  Общее время обработки предложения: 0.42 сек
#
# --- Предложение 11 ---
# Текст: Сельхоз. поляны в Загубье, у тропы в Липовицы.
# ⏱ Время NLP обработки: 0.5394 сек
# 📍 Топоним: Сельхоз (найден за 0.0000 сек)
#     Поиск топонима 'Сельхоз': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сельхоз': 0.0004 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Сельхоз': 0.0006 сек
# 📍 Топоним: Загубье (найден за 0.0006 сек)
#     Поиск топонима 'Загубье': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Загубье': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Загубье': 0.0004 сек
# 📍 Топоним: Липовицы (найден за 0.0004 сек)
#     Поиск топонима 'Липовицы': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Липовицы': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Липовицы': 0.0004 сек
#  Общее время обработки предложения: 0.54 сек
#
# --- Предложение 12 ---
# Текст: Пожня на с/в от деревни, в направлении Типиниц, вытянута с севера на юг, перед обширным болотом.
# ⏱ Время NLP обработки: 0.8273 сек
# 📍 Топоним: Типиниц (найден за 0.0000 сек)
#     Поиск топонима 'Типиниц': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиниц': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Типиниц': 0.0007 сек
#  Общее время обработки предложения: 0.83 сек
#
# --- Предложение 13 ---
# Текст: Дом в дер. Четчойла.
# ⏱ Время NLP обработки: 0.3081 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.31 сек
#
# --- Предложение 14 ---
# Текст: Поляна, расположенная в 1,5 км юго-западнее д.Вороний Остров, посередине между дорогой (на д.Типиниц...
# ⏱ Время NLP обработки: 1.1041 сек
# 📍 Топоним: Вороний Остров (найден за 0.0000 сек)
#     Поиск топонима 'Вороний Остров': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вороний Остров': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Вороний Остров': 0.0007 сек
# 📍 Топоним: Типиницы (найден за 0.0007 сек)
#     Поиск топонима 'Типиницы': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиницы': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Типиницы': 0.0007 сек
# 📍 Топоним: Онежским озером (найден за 0.0007 сек)
#     Поиск топонима 'Онежским озером': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Онежским озером': 0.0003 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Онежским озером': 0.0005 сек
#  Общее время обработки предложения: 1.11 сек
#
# --- Предложение 15 ---
# Текст: Поле в 1км на север от д.Вороний Остров. Рядом Малая Избушка.
# ⏱ Время NLP обработки: 0.6672 сек
# 📍 Топоним: Вороний Остров (найден за 0.0000 сек)
#     Поиск топонима 'Вороний Остров': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вороний Остров': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Вороний Остров': 0.0006 сек
# 📍 Топоним: Малая Избушка (найден за 0.0006 сек)
#     Поиск топонима 'Малая Избушка': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Малая Избушка': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Малая Избушка': 0.0004 сек
#  Общее время обработки предложения: 0.67 сек
#
# --- Предложение 16 ---
# Текст: Покос по ручью Kor'boja.
# ⏱ Время NLP обработки: 0.3221 сек
# 📍 Топоним: Kor'boja (найден за 0.0000 сек)
#     Поиск топонима 'Kor'boja': 0.0002 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Kor'boja': 0.0003 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Kor'boja': 0.0005 сек
#  Общее время обработки предложения: 0.32 сек
#
# --- Предложение 17 ---
# Текст: Болото у оз. Sard'är'f.
# ⏱ Время NLP обработки: 0.3329 сек
# 📍 Топоним: Sard'är'f (найден за 0.0000 сек)
#     Поиск топонима 'Sard'är'f': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Sard'är'f': 0.0003 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Sard'är'f': 0.0005 сек
#     Найдено сокращение: 'оз.' -> 'озеро'
#  Общее время обработки предложения: 0.33 сек
#
# --- Предложение 18 ---
# Текст: Пожога за урочищем Rustadm'äged.
# ⏱ Время NLP обработки: 0.3861 сек
# 📍 Топоним: Rustadm'äged (найден за 0.0000 сек)
#     Поиск топонима 'Rustadm'äged': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Rustadm'äged': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Rustadm'äged': 0.0005 сек
#  Общее время обработки предложения: 0.39 сек
#
# --- Предложение 19 ---
# Текст: На озере Сарозеро.
# ⏱ Время NLP обработки: 0.2598 сек
# 📍 Топоним: Сарозеро (найден за 0.0000 сек)
#     Поиск топонима 'Сарозеро': 0.0002 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сарозеро': 0.0003 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Сарозеро': 0.0005 сек
#  Общее время обработки предложения: 0.26 сек
#
#  Прогресс: обработано 20/100 предложений
#  Прошло времени: 0:00:11
#  Среднее время поиска сокращений на топоним: 0.0007 сек
#  Среднее время NLP: 0.5907 сек
#  Оставшееся время: ~0:00:47
#
# --- Предложение 20 ---
# Текст: Ламба в 1,5 км на север от дер. Сеппяваара в сторону дер. Варлов Лес.
# ⏱ Время NLP обработки: 0.5944 сек
# 📍 Топоним: Ламба (найден за 0.0000 сек)
#     Поиск топонима 'Ламба': 0.0002 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Ламба': 0.0004 сек
#     Найдено 1 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Ламба': 0.0006 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.60 сек
#
# --- Предложение 21 ---
# Текст: Лесное урочище в болота Узкие мошки, в истоках ручья, впадающего в Калейгубу в урочище Уромы.
# ⏱ Время NLP обработки: 0.8364 сек
# 📍 Топоним: Узкие мошки (найден за 0.0000 сек)
#     Поиск топонима 'Узкие мошки': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Узкие мошки': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Узкие мошки': 0.0006 сек
# 📍 Топоним: Калейгубу (найден за 0.0006 сек)
#     Поиск топонима 'Калейгубу': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Калейгубу': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Калейгубу': 0.0003 сек
# 📍 Топоним: Уромы (найден за 0.0003 сек)
#     Поиск топонима 'Уромы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Уромы': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Уромы': 0.0003 сек
#  Общее время обработки предложения: 0.84 сек
#
# --- Предложение 22 ---
# Текст: Поле на одноименном мысу, юго-запад Красного поля д.Сибово.
# ⏱ Время NLP обработки: 0.6105 сек
# 📍 Топоним: Красного поля (найден за 0.0000 сек)
#     Поиск топонима 'Красного поля': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Красного поля': 0.0005 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Красного поля': 0.0007 сек
# 📍 Топоним: Сибово (найден за 0.0007 сек)
#     Поиск топонима 'Сибово': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сибово': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Сибово': 0.0004 сек
#  Общее время обработки предложения: 0.61 сек
#
# --- Предложение 23 ---
# Текст: Мыс на южном берегу оз.Кемское, прежде была деревня
# ⏱ Время NLP обработки: 0.5060 сек
# 📍 Топоним: Кемское (найден за 0.0000 сек)
#     Поиск топонима 'Кемское': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Кемское': 0.0004 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Кемское': 0.0006 сек
#  Общее время обработки предложения: 0.51 сек
#
# --- Предложение 24 ---
# Текст: Ручей в 1,8 км к северо-востоку от д.Сибово.
# ⏱ Время NLP обработки: 0.5160 сек
# 📍 Топоним: Сибово (найден за 0.0000 сек)
#     Поиск топонима 'Сибово': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сибово': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Сибово': 0.0005 сек
#  Общее время обработки предложения: 0.52 сек
#
# --- Предложение 25 ---
# Текст: Один из островов в Красном поле, юго-западнее д.Сибово.
# ⏱ Время NLP обработки: 0.5775 сек
# 📍 Топоним: Красном поле (найден за 0.0000 сек)
#     Поиск топонима 'Красном поле': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Красном поле': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Красном поле': 0.0007 сек
# 📍 Топоним: Сибово (найден за 0.0007 сек)
#     Поиск топонима 'Сибово': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сибово': 0.0005 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Сибово': 0.0005 сек
#  Общее время обработки предложения: 0.58 сек
#
# --- Предложение 26 ---
# Текст: Покос на р. Большая Сенатка.
# ⏱ Время NLP обработки: 0.3126 сек
# 📍 Топоним: Большая Сенатка (найден за 0.0000 сек)
#     Поиск топонима 'Большая Сенатка': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Большая Сенатка': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Большая Сенатка': 0.0005 сек
#     Найдено сокращение: 'р.' -> 'ручей'
#  Общее время обработки предложения: 0.31 сек
#
# --- Предложение 27 ---
# Текст: Покос в урочище Šidroja.
# ⏱ Время NLP обработки: 0.3024 сек
# 📍 Топоним: Šidroja (найден за 0.0000 сек)
#     Поиск топонима 'Šidroja': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Šidroja': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Šidroja': 0.0004 сек
#  Общее время обработки предложения: 0.30 сек
#
# --- Предложение 28 ---
# Текст: Ближайший из группы островов на юго-востоке от южной оконечности о.Вигово, в 500 м от берега.
# ⏱ Время NLP обработки: 1.0809 сек
# 📍 Топоним: Вигово (найден за 0.0000 сек)
#     Поиск топонима 'Вигово': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вигово': 0.0007 сек
#     Сокращения не найдены за 0.0009 сек
#     Общее время поиска сокращений для 'Вигово': 0.0009 сек
#  Общее время обработки предложения: 1.08 сек
#
# --- Предложение 29 ---
# Текст: Болото (дер. Перелесок), примыкающее к оз. Vaagedjär'v.
# ⏱ Время NLP обработки: 0.7332 сек
# 📍 Топоним: Перелесок (найден за 0.0000 сек)
#     Поиск топонима 'Перелесок': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Перелесок': 0.0007 сек
#     Найдено 2 сокращений за 0.0008 сек
#     Общее время поиска сокращений для 'Перелесок': 0.0008 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#     Найдено сокращение: 'оз.' -> 'озеро'
# 📍 Топоним: Vaagedjär'v (найден за 0.0008 сек)
#     Поиск топонима 'Vaagedjär'v': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Vaagedjär'v': 0.0008 сек
#     Найдено 2 сокращений за 0.0008 сек
#     Общее время поиска сокращений для 'Vaagedjär'v': 0.0008 сек
#  Общее время обработки предложения: 0.74 сек
#
#  Прогресс: обработано 30/100 предложений
#  Прошло времени: 0:00:17
#  Среднее время поиска сокращений на топоним: 0.0006 сек
#  Среднее время NLP: 0.5961 сек
#  Оставшееся время: ~0:00:41
#
# --- Предложение 30 ---
# Текст: Покос (дер. Aksintanaz) за урочищем N'ekojain'e.
# ⏱ Время NLP обработки: 0.6862 сек
# 📍 Топоним: Aksintanaz (найден за 0.0000 сек)
#     Поиск топонима 'Aksintanaz': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Aksintanaz': 0.0008 сек
#     Найдено 1 сокращений за 0.0009 сек
#     Общее время поиска сокращений для 'Aksintanaz': 0.0009 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
# 📍 Топоним: N'ekojain'e (найден за 0.0009 сек)
#     Поиск топонима 'N'ekojain'e': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'N'ekojain'e': 0.0006 сек
#     Найдено 1 сокращений за 0.0007 сек
#     Общее время поиска сокращений для 'N'ekojain'e': 0.0007 сек
#  Общее время обработки предложения: 0.69 сек
#
# --- Предложение 31 ---
# Текст: Поле (дер. Aksintanaz).
# ⏱ Время NLP обработки: 0.3006 сек
# 📍 Топоним: Aksintanaz (найден за 0.0000 сек)
#     Поиск топонима 'Aksintanaz': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Aksintanaz': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Aksintanaz': 0.0004 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.30 сек
#
# --- Предложение 32 ---
# Текст: Покосы.
# ⏱ Время NLP обработки: 0.1632 сек
# 📍 Топоним: Покосы (найден за 0.0000 сек)
#     Поиск топонима 'Покосы': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Покосы': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Покосы': 0.0004 сек
#  Общее время обработки предложения: 0.16 сек
#
# --- Предложение 33 ---
# Текст: Река, вытекающая из оз. Яндомозеро в южной его части, протекающая на юго-восток и впадающая в Онежск...
# ⏱ Время NLP обработки: 1.2765 сек
# 📍 Топоним: Онежское озеро (найден за 0.0000 сек)
#     Поиск топонима 'Онежское озеро': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Онежское озеро': 0.0005 сек
#     Найдено 1 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Онежское озеро': 0.0006 сек
#     Найдено сокращение: 'д.' -> 'дом'
# 📍 Топоним: Усть-Яндома (найден за 0.0006 сек)
#     Поиск топонима 'Усть-Яндома': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Усть-Яндома': 0.0007 сек
#     Найдено 1 сокращений за 0.0008 сек
#     Общее время поиска сокращений для 'Усть-Яндома': 0.0008 сек
#  Общее время обработки предложения: 1.28 сек
#
# --- Предложение 34 ---
# Текст: Озеро (басс. р. Иводы), в 2 км. от дер. Пустошка.
# ⏱ Время NLP обработки: 0.5494 сек
# 📍 Топоним: Иводы (найден за 0.0000 сек)
#     Поиск топонима 'Иводы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Иводы': 0.0005 сек
#     Найдено 2 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Иводы': 0.0006 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#     Найдено сокращение: 'р.' -> 'ручей'
# 📍 Топоним: Пустошка (найден за 0.0006 сек)
#     Поиск топонима 'Пустошка': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пустошка': 0.0003 сек
#     Найдено 2 сокращений за 0.0003 сек
#     Общее время поиска сокращений для 'Пустошка': 0.0003 сек
#  Общее время обработки предложения: 0.55 сек
#
# --- Предложение 35 ---
# Текст: Ламба в 2,3 км на с/з от дер. Сеппяваара в сторону дер. Воронова Сельга.
# ⏱ Время NLP обработки: 0.5863 сек
# 📍 Топоним: Ламба (найден за 0.0000 сек)
#     Поиск топонима 'Ламба': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Ламба': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Ламба': 0.0005 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.59 сек
#
# --- Предложение 36 ---
# Текст: Покос (дер. Панкратово) на берегу оз. Sepad'är'v.
# ⏱ Время NLP обработки: 0.4842 сек
# 📍 Топоним: Панкратово (найден за 0.0000 сек)
#     Поиск топонима 'Панкратово': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Панкратово': 0.0005 сек
#     Найдено 2 сокращений за 0.0007 сек
#     Общее время поиска сокращений для 'Панкратово': 0.0007 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#     Найдено сокращение: 'оз.' -> 'озеро'
# 📍 Топоним: Sepad'är'v (найден за 0.0007 сек)
#     Поиск топонима 'Sepad'är'v': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Sepad'är'v': 0.0003 сек
#     Найдено 2 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Sepad'är'v': 0.0004 сек
#  Общее время обработки предложения: 0.49 сек
#
# --- Предложение 37 ---
# Текст: Ручей, течет из оз. Sagažg'är'v в оз. S'epatg'är, название связывают с тем, что oja astub korbedm'e ...
# ⏱ Время NLP обработки: 1.0416 сек
# 📍 Топоним: Ручей (найден за 0.0000 сек)
#     Поиск топонима 'Ручей': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Ручей': 0.0004 сек
#     Найдено 2 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Ручей': 0.0005 сек
#     Найдено сокращение: 'оз.' -> 'озеро'
#  Общее время обработки предложения: 1.04 сек
#
# --- Предложение 38 ---
# Текст:  Поляна из группы полян, расположенных в 100 м от южной оконечности д. Саньки.
# ⏱ Время NLP обработки: 0.6903 сек
# 📍 Топоним: Саньки (найден за 0.0000 сек)
#     Поиск топонима 'Саньки': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Саньки': 0.0004 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Саньки': 0.0004 сек
#     Найдено сокращение: 'д.' -> 'дом'
#  Общее время обработки предложения: 0.69 сек
#
# --- Предложение 39 ---
# Текст: Часть оз. Нинисельгское, где купались.
# ⏱ Время NLP обработки: 0.4250 сек
# 📍 Топоним: Нинисельгское (найден за 0.0000 сек)
#     Поиск топонима 'Нинисельгское': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Нинисельгское': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Нинисельгское': 0.0005 сек
#     Найдено сокращение: 'оз.' -> 'озеро'
#  Общее время обработки предложения: 0.43 сек
#
#  Прогресс: обработано 40/100 предложений
#  Прошло времени: 0:00:24
#  Среднее время поиска сокращений на топоним: 0.0006 сек
#  Среднее время NLP: 0.6022 сек
#  Оставшееся время: ~0:00:36
#
# --- Предложение 40 ---
# Текст:  Полянка на западе д. Углевщина.
# ⏱ Время NLP обработки: 0.3686 сек
# 📍 Топоним: Углевщина (найден за 0.0000 сек)
#     Поиск топонима 'Углевщина': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Углевщина': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Углевщина': 0.0004 сек
#     Найдено сокращение: 'д.' -> 'дом'
#  Общее время обработки предложения: 0.37 сек
#
# --- Предложение 41 ---
# Текст: Деревня (бывшая) на с/в от Типиниц, на высоком месте.
# ⏱ Время NLP обработки: 0.6342 сек
# 📍 Топоним: Типиниц (найден за 0.0000 сек)
#     Поиск топонима 'Типиниц': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиниц': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Типиниц': 0.0005 сек
#  Общее время обработки предложения: 0.63 сек
#
# --- Предложение 42 ---
# Текст: Болото по направлению к дер. Бор, по сведениям информатора Mat'er'eiso.
# ⏱ Время NLP обработки: 0.7221 сек
# 📍 Топоним: Болото (найден за 0.0000 сек)
#     Поиск топонима 'Болото': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Болото': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Болото': 0.0005 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.72 сек
#
# --- Предложение 43 ---
# Текст: Пахотная поляна на северной окраине деревни, у ручья, впадающего в Онежское озеро.
# ⏱ Время NLP обработки: 0.7136 сек
# 📍 Топоним: Онежское озеро (найден за 0.0000 сек)
#     Поиск топонима 'Онежское озеро': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Онежское озеро': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Онежское озеро': 0.0004 сек
#  Общее время обработки предложения: 0.71 сек
#
# --- Предложение 44 ---
# Текст: Луда на Яндомозере у Карельских островов.
# ⏱ Время NLP обработки: 0.3984 сек
# 📍 Топоним: Яндомозере (найден за 0.0000 сек)
#     Поиск топонима 'Яндомозере': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Яндомозере': 0.0003 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Яндомозере': 0.0005 сек
# 📍 Топоним: Карельских островов (найден за 0.0005 сек)
#     Поиск топонима 'Карельских островов': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Карельских островов': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Карельских островов': 0.0003 сек
#  Общее время обработки предложения: 0.40 сек
#
# --- Предложение 45 ---
# Текст: Бывший пожог в урочище Kalaidai.
# ⏱ Время NLP обработки: 0.3407 сек
# 📍 Топоним: Kalaidai (найден за 0.0000 сек)
#     Поиск топонима 'Kalaidai': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Kalaidai': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Kalaidai': 0.0004 сек
#  Общее время обработки предложения: 0.34 сек
#
# --- Предложение 46 ---
# Текст: см. Корбозеро
# ⏱ Время NLP обработки: 0.2277 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.23 сек
#
# --- Предложение 47 ---
# Текст: Бывший хутор у дер. Laht (Лахта).
# ⏱ Время NLP обработки: 0.4053 сек
# 📍 Топоним: Laht (найден за 0.0000 сек)
#     Поиск топонима 'Laht': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Laht': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Laht': 0.0005 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
# 📍 Топоним: Лахта (найден за 0.0005 сек)
#     Поиск топонима 'Лахта': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Лахта': 0.0002 сек
#     Найдено 1 сокращений за 0.0003 сек
#     Общее время поиска сокращений для 'Лахта': 0.0003 сек
#  Общее время обработки предложения: 0.41 сек
#
# --- Предложение 48 ---
# Текст:  Покос на Яндомозере, см. Виднаволок - мыс.
# ⏱ Время NLP обработки: 0.4403 сек
# 📍 Топоним: Яндомозере (найден за 0.0000 сек)
#     Поиск топонима 'Яндомозере': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Яндомозере': 0.0005 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Яндомозере': 0.0005 сек
#     Найдено сокращение: 'мыс' -> 'мыс'
# 📍 Топоним: Виднаволок (найден за 0.0005 сек)
#     Поиск топонима 'Виднаволок': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Виднаволок': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Виднаволок': 0.0004 сек
#  Общее время обработки предложения: 0.44 сек
#
# --- Предложение 49 ---
# Текст: Пахотная поляна в лесу, у дороги на Корбозеро.
# ⏱ Время NLP обработки: 0.6297 сек
# 📍 Топоним: Корбозеро (найден за 0.0000 сек)
#     Поиск топонима 'Корбозеро': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Корбозеро': 0.0006 сек
#     Сокращения не найдены за 0.0008 сек
#     Общее время поиска сокращений для 'Корбозеро': 0.0008 сек
#  Общее время обработки предложения: 0.63 сек
#
#  Прогресс: обработано 50/100 предложений
#  Прошло времени: 0:00:29
#  Среднее время поиска сокращений на топоним: 0.0006 сек
#  Среднее время NLP: 0.5794 сек
#  Оставшееся время: ~0:00:29
#
# --- Предложение 50 ---
# Текст: Часть пруда Luhtu, по хозяину дома.
# ⏱ Время NLP обработки: 0.5260 сек
# 📍 Топоним: Luhtu (найден за 0.0000 сек)
#     Поиск топонима 'Luhtu': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Luhtu': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Luhtu': 0.0007 сек
#  Общее время обработки предложения: 0.53 сек
#
# --- Предложение 51 ---
# Текст: Остров на озере Sar'jar'v.
# ⏱ Время NLP обработки: 0.3876 сек
# 📍 Топоним: Sar'jar'v (найден за 0.0000 сек)
#     Поиск топонима 'Sar'jar'v': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Sar'jar'v': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Sar'jar'v': 0.0007 сек
#  Общее время обработки предложения: 0.39 сек
#
# --- Предложение 52 ---
# Текст: Поле в дер. Тигвера рядом с местом слияния рек Тигверки и Тулосозера.
# ⏱ Время NLP обработки: 0.9854 сек
# 📍 Топоним: Тигверки (найден за 0.0000 сек)
#     Поиск топонима 'Тигверки': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Тигверки': 0.0007 сек
#     Сокращения не найдены за 0.0008 сек
#     Общее время поиска сокращений для 'Тигверки': 0.0008 сек
# 📍 Топоним: Тулосозера (найден за 0.0009 сек)
#     Поиск топонима 'Тулосозера': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Тулосозера': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Тулосозера': 0.0006 сек
#  Общее время обработки предложения: 0.99 сек
#
# --- Предложение 53 ---
# Текст: Мост через реку Тигверку.
# ⏱ Время NLP обработки: 0.3020 сек
# 📍 Топоним: Тигверку (найден за 0.0000 сек)
#     Поиск топонима 'Тигверку': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Тигверку': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Тигверку': 0.0004 сек
#  Общее время обработки предложения: 0.30 сек
#
# --- Предложение 54 ---
# Текст: Урочище вокруг моста.
# ⏱ Время NLP обработки: 0.2715 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.27 сек
#
# --- Предложение 55 ---
# Текст: С/х угодье (поляны), бывшие подсеки, в лесу.
# ⏱ Время NLP обработки: 0.4661 сек
# 📍 Топоним: С/х угодье (найден за 0.0000 сек)
#     Поиск топонима 'С/х угодье': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'С/х угодье': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'С/х угодье': 0.0006 сек
#  Общее время обработки предложения: 0.47 сек
#
# --- Предложение 56 ---
# Текст: Озеро по направлению к Пелушам, в стороне от дороги.
# ⏱ Время NLP обработки: 0.4906 сек
# 📍 Топоним: Пелушам (найден за 0.0000 сек)
#     Поиск топонима 'Пелушам': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пелушам': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Пелушам': 0.0005 сек
#  Общее время обработки предложения: 0.49 сек
#
# --- Предложение 57 ---
# Текст: Пахотная поляна к северу от деревни, у Лельреки.
# ⏱ Время NLP обработки: 0.4775 сек
# 📍 Топоним: Пахотная поляна (найден за 0.0000 сек)
#     Поиск топонима 'Пахотная поляна': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пахотная поляна': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Пахотная поляна': 0.0004 сек
# 📍 Топоним: Лельреки (найден за 0.0004 сек)
#     Поиск топонима 'Лельреки': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Лельреки': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Лельреки': 0.0003 сек
#  Общее время обработки предложения: 0.48 сек
#
# --- Предложение 58 ---
# Текст: Поле к северу от Педейнаволока, на берегу залива Великая Губа.
# ⏱ Время NLP обработки: 0.5654 сек
# 📍 Топоним: Педейнаволока (найден за 0.0000 сек)
#     Поиск топонима 'Педейнаволока': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Педейнаволока': 0.0004 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Педейнаволока': 0.0006 сек
# 📍 Топоним: Великая Губа (найден за 0.0006 сек)
#     Поиск топонима 'Великая Губа': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Великая Губа': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Великая Губа': 0.0004 сек
#  Общее время обработки предложения: 0.57 сек
#
# --- Предложение 59 ---
# Текст: Бывшая деревня Подовинники.
# ⏱ Время NLP обработки: 0.3243 сек
# 📍 Топоним: Подовинники (найден за 0.0000 сек)
#     Поиск топонима 'Подовинники': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Подовинники': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Подовинники': 0.0004 сек
#  Общее время обработки предложения: 0.32 сек
#
#  Прогресс: обработано 60/100 предложений
#  Прошло времени: 0:00:33
#  Среднее время поиска сокращений на топоним: 0.0006 сек
#  Среднее время NLP: 0.5627 сек
#  Оставшееся время: ~0:00:22
#
# --- Предложение 60 ---
# Текст: Исток ручья Šoudoja.
# ⏱ Время NLP обработки: 0.2495 сек
# 📍 Топоним: Šoudoja (найден за 0.0000 сек)
#     Поиск топонима 'Šoudoja': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Šoudoja': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Šoudoja': 0.0004 сек
#  Общее время обработки предложения: 0.25 сек
#
# --- Предложение 61 ---
# Текст: Болото в 2 км. от дер., в истоках ручья Mel'n'icojain'e.
# ⏱ Время NLP обработки: 0.5628 сек
# 📍 Топоним: Mel'n'icojain'e (найден за 0.0000 сек)
#     Поиск топонима 'Mel'n'icojain'e': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Mel'n'icojain'e': 0.0004 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Mel'n'icojain'e': 0.0004 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.56 сек
#
# --- Предложение 62 ---
# Текст: Деревня за дер. Нойдала.
# ⏱ Время NLP обработки: 0.3368 сек
# 📍 Топоним: Нойдала (найден за 0.0000 сек)
#     Поиск топонима 'Нойдала': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Нойдала': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Нойдала': 0.0004 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.34 сек
#
# --- Предложение 63 ---
# Текст: Поляна к с/в от д.Поля в 1,5 км, на высоком месте.
# ⏱ Время NLP обработки: 0.5147 сек
# 📍 Топоним: Поля (найден за 0.0000 сек)
#     Поиск топонима 'Поля': 0.0000 сек, найдено 2 вхождений
#     Поиск сокращений вокруг 'Поля': 0.0003 сек
#     Поиск сокращений вокруг 'Поля': 0.0003 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Поля': 0.0007 сек
#  Общее время обработки предложения: 0.52 сек
#
# --- Предложение 64 ---
# Текст: Покос на р. Šalg'ögi, при впадении ручья Rihoja, выше моста Lava.
# ⏱ Время NLP обработки: 0.6151 сек
# 📍 Топоним: Šalg'ögi (найден за 0.0000 сек)
#     Поиск топонима 'Šalg'ögi': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Šalg'ögi': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Šalg'ögi': 0.0005 сек
#     Найдено сокращение: 'р.' -> 'ручей'
# 📍 Топоним: Rihoja (найден за 0.0005 сек)
#     Поиск топонима 'Rihoja': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Rihoja': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Rihoja': 0.0004 сек
# 📍 Топоним: моста Lava (найден за 0.0004 сек)
#     Поиск топонима 'моста Lava': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'моста Lava': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'моста Lava': 0.0003 сек
#  Общее время обработки предложения: 0.62 сек
#
# --- Предложение 65 ---
# Текст: Бывшая деревня у Лахты.
# ⏱ Время NLP обработки: 0.2553 сек
# 📍 Топоним: Лахты (найден за 0.0000 сек)
#     Поиск топонима 'Лахты': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Лахты': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Лахты': 0.0005 сек
#  Общее время обработки предложения: 0.26 сек
#
# --- Предложение 66 ---
# Текст: Место на западном берегу Яндомозера, куда приставали на лодках едущие из Марковщины в Великую Губу.
# ⏱ Время NLP обработки: 0.8660 сек
# 📍 Топоним: Яндомозера (найден за 0.0000 сек)
#     Поиск топонима 'Яндомозера': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Яндомозера': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Яндомозера': 0.0005 сек
# 📍 Топоним: Марковщины (найден за 0.0005 сек)
#     Поиск топонима 'Марковщины': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Марковщины': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Марковщины': 0.0004 сек
# 📍 Топоним: Великую Губу (найден за 0.0004 сек)
#     Поиск топонима 'Великую Губу': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Великую Губу': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Великую Губу': 0.0004 сек
#  Общее время обработки предложения: 0.87 сек
#
# --- Предложение 67 ---
# Текст: Покос на берегу Виговской губы, между Педейнаволоком и устьем Лейреки. Принадлежал семье наиболее бо...
# ⏱ Время NLP обработки: 1.1501 сек
# 📍 Топоним: Виговской губы (найден за 0.0000 сек)
#     Поиск топонима 'Виговской губы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Виговской губы': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Виговской губы': 0.0005 сек
# 📍 Топоним: Педейнаволоком (найден за 0.0005 сек)
#     Поиск топонима 'Педейнаволоком': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Педейнаволоком': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Педейнаволоком': 0.0005 сек
# 📍 Топоним: Лейреки (найден за 0.0005 сек)
#     Поиск топонима 'Лейреки': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Лейреки': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Лейреки': 0.0004 сек
# 📍 Топоним: Корельских (найден за 0.0004 сек)
#     Поиск топонима 'Корельских': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Корельских': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Корельских': 0.0004 сек
# 📍 Топоним: Корельского (найден за 0.0004 сек)
#     Поиск топонима 'Корельского': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Корельского': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Корельского': 0.0004 сек
# 📍 Топоним: Вигово (найден за 0.0004 сек)
#     Поиск топонима 'Вигово': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вигово': 0.0003 сек
#     Найдено 1 сокращений за 0.0003 сек
#     Общее время поиска сокращений для 'Вигово': 0.0003 сек
#     Найдено сокращение: 'х.' -> 'хутор'
#  Общее время обработки предложения: 1.15 сек
#
# --- Предложение 68 ---
# Текст: Болотистый сенокос к западу от урочища Кумбыша, у Ушового моста. С севера к нему примыкает Северница...
# ⏱ Время NLP обработки: 1.0310 сек
# 📍 Топоним: Кумбыша (найден за 0.0000 сек)
#     Поиск топонима 'Кумбыша': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Кумбыша': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Кумбыша': 0.0006 сек
# 📍 Топоним: Ушового моста (найден за 0.0006 сек)
#     Поиск топонима 'Ушового моста': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Ушового моста': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Ушового моста': 0.0005 сек
# 📍 Топоним: Северница (найден за 0.0005 сек)
#     Поиск топонима 'Северница': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Северница': 0.0003 сек
# ...
#     Поиск сокращений вокруг 'Усть-Яндома': 0.0008 сек
#     Найдено 1 сокращений за 0.0009 сек
#     Общее время поиска сокращений для 'Усть-Яндома': 0.0009 сек
#     Найдено сокращение: 'д.' -> 'дом'
# 📍 Топоним: Типиницы (найден за 0.0009 сек)
#     Поиск топонима 'Типиницы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиницы': 0.0007 сек
#     Найдено 1 сокращений за 0.0007 сек
#     Общее время поиска сокращений для 'Типиницы': 0.0007 сек
# 📍 Топоним: Глубоким Ручьем (найден за 0.0007 сек)
#     Поиск топонима 'Глубоким Ручьем': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Глубоким Ручьем': 0.0007 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Глубоким Ручьем': 0.0007 сек
# 📍 Топоним: Средняя Пихтеревщина (найден за 0.0007 сек)
#     Поиск топонима 'Средняя Пихтеревщина': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Средняя Пихтеревщина': 0.0006 сек
#     Сокращения не найдены за 0.0007 сек
#     Общее время поиска сокращений для 'Средняя Пихтеревщина': 0.0007 сек
#  Общее время обработки предложения: 1.45 сек
#
# --- Предложение 73 ---
# Текст: Урочище (лесное), где росли грибы (дер. Сташково Радогощенский с/с).
# ⏱ Время NLP обработки: 0.9166 сек
# 📍 Топоним: Сташково Радогощенский с/с (найден за 0.0000 сек)
#     Поиск топонима 'Сташково Радогощенский с/с': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Сташково Радогощенский с/с': 0.0007 сек
#     Найдено 1 сокращений за 0.0009 сек
#     Общее время поиска сокращений для 'Сташково Радогощенский с/с': 0.0009 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.92 сек
#
# --- Предложение 74 ---
# Текст: Бывшая деревня на водоразделе, на высоком месте.
# ⏱ Время NLP обработки: 0.5617 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.56 сек
#
# --- Предложение 75 ---
# Текст: Горка у озера в деревне на месте нового колодца.
# ⏱ Время NLP обработки: 0.4665 сек
# 📍 Топоним: Горка (найден за 0.0000 сек)
#     Поиск топонима 'Горка': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Горка': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Горка': 0.0004 сек
#  Общее время обработки предложения: 0.47 сек
#
# --- Предложение 76 ---
# Текст: Поле на мысу, вдающемсяс юга в болото напротив д. Задняя.
# ⏱ Время NLP обработки: 0.5816 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.58 сек
#
# --- Предложение 77 ---
# Текст: Пожня
# ⏱ Время NLP обработки: 0.1264 сек
# 📍 Топоним: Пожня (найден за 0.0000 сек)
#     Поиск топонима 'Пожня': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пожня': 0.0002 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Пожня': 0.0003 сек
#  Общее время обработки предложения: 0.13 сек
#
# --- Предложение 78 ---
# Текст: Ручей, течет из оз. Lidnag'är'v.
# ⏱ Время NLP обработки: 0.3768 сек
# 📍 Топоним: Lidnag'är'v (найден за 0.0000 сек)
#     Поиск топонима 'Lidnag'är'v': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Lidnag'är'v': 0.0003 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Lidnag'är'v': 0.0004 сек
#     Найдено сокращение: 'оз.' -> 'озеро'
#  Общее время обработки предложения: 0.38 сек
#
# --- Предложение 79 ---
# Текст: Мыс, расположенный в 0,5 км на север от о.Вороний.
# ⏱ Время NLP обработки: 0.5078 сек
# 📍 Топоним: Вороний (найден за 0.0000 сек)
#     Поиск топонима 'Вороний': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вороний': 0.0007 сек
#     Сокращения не найдены за 0.0008 сек
#     Общее время поиска сокращений для 'Вороний': 0.0008 сек
#  Общее время обработки предложения: 0.51 сек
#
#  Прогресс: обработано 80/100 предложений
#  Прошло времени: 0:00:45
#  Среднее время поиска сокращений на топоним: 0.0006 сек
#  Среднее время NLP: 0.5704 сек
#  Оставшееся время: ~0:00:11
#
# --- Предложение 80 ---
# Текст: Место рыбной ловли в Великой губе, 1,5 км на запад от д.Вигово.
# ⏱ Время NLP обработки: 0.5787 сек
# 📍 Топоним: Великой губе (найден за 0.0000 сек)
#     Поиск топонима 'Великой губе': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Великой губе': 0.0004 сек
#     Сокращения не найдены за 0.0005 сек
#     Общее время поиска сокращений для 'Великой губе': 0.0005 сек
# 📍 Топоним: Вигово (найден за 0.0005 сек)
#     Поиск топонима 'Вигово': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Вигово': 0.0002 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Вигово': 0.0003 сек
#  Общее время обработки предложения: 0.58 сек
#
# --- Предложение 81 ---
# Текст:  Покосы, 2 км на север от Марковщины, по дороге в Мягкую Сельгу (Космозерский с/с), у болотины, чере...
# ⏱ Время NLP обработки: 1.0067 сек
# 📍 Топоним: Покосы (найден за 0.0000 сек)
#     Поиск топонима 'Покосы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Покосы': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Покосы': 0.0004 сек
# 📍 Топоним: Марковщины (найден за 0.0004 сек)
#     Поиск топонима 'Марковщины': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Марковщины': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Марковщины': 0.0004 сек
# 📍 Топоним: Мягкую Сельгу (найден за 0.0004 сек)
#     Поиск топонима 'Мягкую Сельгу': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Мягкую Сельгу': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Мягкую Сельгу': 0.0004 сек
# 📍 Топоним: Космозерский с/с (найден за 0.0004 сек)
#     Поиск топонима 'Космозерский с/с': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Космозерский с/с': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Космозерский с/с': 0.0004 сек
#  Общее время обработки предложения: 1.01 сек
#
# --- Предложение 82 ---
# Текст: Озеро (ламба) в деревне.
# ⏱ Время NLP обработки: 0.3250 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.33 сек
#
# --- Предложение 83 ---
# Текст: покос, 0.5 км на юго-запад от д. Истомино, на мысу Саньковский Наволок
# ⏱ Время NLP обработки: 0.6880 сек
# 📍 Топоним: Саньковский Наволок (найден за 0.0000 сек)
#     Поиск топонима 'Саньковский Наволок': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Саньковский Наволок': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Саньковский Наволок': 0.0005 сек
#     Найдено сокращение: 'д.' -> 'дом'
#  Общее время обработки предложения: 0.69 сек
#
# --- Предложение 84 ---
# Текст: Озеро в 3 верстах от дер (басс. р Колпь).
# ⏱ Время NLP обработки: 0.4488 сек
# 📍 Топоним: Колпь (найден за 0.0000 сек)
#     Поиск топонима 'Колпь': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Колпь': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Колпь': 0.0004 сек
#  Общее время обработки предложения: 0.45 сек
#
# --- Предложение 85 ---
# Текст: Болото в 0, 5 км на с/в от дер. Четчойла
# ⏱ Время NLP обработки: 0.4591 сек
# 📍 Топоним: Болото (найден за 0.0000 сек)
#     Поиск топонима 'Болото': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Болото': 0.0004 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Болото': 0.0005 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.46 сек
#
# --- Предложение 86 ---
# Текст: Пожня
# ⏱ Время NLP обработки: 0.1331 сек
# 📍 Топоним: Пожня (найден за 0.0000 сек)
#     Поиск топонима 'Пожня': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пожня': 0.0002 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Пожня': 0.0003 сек
#  Общее время обработки предложения: 0.13 сек
#
# --- Предложение 87 ---
# Текст: Река, находится в 300 м от д.Типиницы на запад.Вытекает из болота у д. Холмы, впадает в Типиницкий з...
# ⏱ Время NLP обработки: 0.8923 сек
# 📍 Топоним: Типиницы (найден за 0.0000 сек)
#     Поиск топонима 'Типиницы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиницы': 0.0005 сек
#     Найдено 1 сокращений за 0.0005 сек
#     Общее время поиска сокращений для 'Типиницы': 0.0005 сек
#     Найдено сокращение: 'д.' -> 'дом'
# 📍 Топоним: Типиницкий залив (найден за 0.0005 сек)
#     Поиск топонима 'Типиницкий залив': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиницкий залив': 0.0004 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Типиницкий залив': 0.0004 сек
# 📍 Топоним: Нулица (найден за 0.0004 сек)
#     Поиск топонима 'Нулица': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Нулица': 0.0002 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Нулица': 0.0003 сек
#  Общее время обработки предложения: 0.89 сек
#
# --- Предложение 88 ---
# Текст: Болото в 3 км. от дер. Turžin.
# ⏱ Время NLP обработки: 0.3691 сек
# 📍 Топоним: Turžin (найден за 0.0000 сек)
#     Поиск топонима 'Turžin': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Turžin': 0.0004 сек
#     Найдено 1 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Turžin': 0.0004 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#  Общее время обработки предложения: 0.37 сек
#
# --- Предложение 89 ---
# Текст: Центральная часть д.Типиницы, на горке
# ⏱ Время NLP обработки: 0.3927 сек
# 📍 Топоним: Типиницы (найден за 0.0000 сек)
#     Поиск топонима 'Типиницы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Типиницы': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Типиницы': 0.0004 сек
#  Общее время обработки предложения: 0.39 сек
#
#  Прогресс: обработано 90/100 предложений
#  Прошло времени: 0:00:51
#  Среднее время поиска сокращений на топоним: 0.0005 сек
#  Среднее время NLP: 0.5659 сек
#  Оставшееся время: ~0:00:05
#
# --- Предложение 90 ---
# Текст: Пахотная полоса.
# ⏱ Время NLP обработки: 0.2305 сек
# 📍 Топоним: Пахотная полоса (найден за 0.0000 сек)
#     Поиск топонима 'Пахотная полоса': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Пахотная полоса': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Пахотная полоса': 0.0003 сек
#  Общее время обработки предложения: 0.23 сек
#
# --- Предложение 91 ---
# Текст: Дорога в деревню Озера.
# ⏱ Время NLP обработки: 0.2712 сек
# 📍 Топоним: Озера (найден за 0.0000 сек)
#     Поиск топонима 'Озера': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Озера': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Озера': 0.0006 сек
#  Общее время обработки предложения: 0.27 сек
#
# --- Предложение 92 ---
# Текст: Омут против дер. Turžin, на р. Иводе, в месте, где река делает колено.
# ⏱ Время NLP обработки: 0.5868 сек
# 📍 Топоним: Омут (найден за 0.0000 сек)
#     Поиск топонима 'Омут': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Омут': 0.0004 сек
#     Найдено 2 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Омут': 0.0004 сек
#     Найдено сокращение: 'дер.' -> 'дерево'
#     Найдено сокращение: 'р.' -> 'ручей'
# 📍 Топоним: Иводе (найден за 0.0004 сек)
#     Поиск топонима 'Иводе': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Иводе': 0.0004 сек
#     Найдено 2 сокращений за 0.0004 сек
#     Общее время поиска сокращений для 'Иводе': 0.0004 сек
#  Общее время обработки предложения: 0.59 сек
#
# --- Предложение 93 ---
# Текст: Порог на реке Ояти.
# ⏱ Время NLP обработки: 0.2626 сек
# 📍 Топоним: Ояти (найден за 0.0000 сек)
#     Поиск топонима 'Ояти': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Ояти': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Ояти': 0.0004 сек
#  Общее время обработки предложения: 0.26 сек
#
# --- Предложение 94 ---
# Текст: Поле к югу от д.Кибитка в в 1 км, у дороги в Никитину.
# ⏱ Время NLP обработки: 0.5337 сек
# 📍 Топоним: Кибитка (найден за 0.0000 сек)
#     Поиск топонима 'Кибитка': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Кибитка': 0.0004 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Кибитка': 0.0004 сек
# 📍 Топоним: Никитину (найден за 0.0004 сек)
#     Поиск топонима 'Никитину': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Никитину': 0.0003 сек
#     Сокращения не найдены за 0.0003 сек
#     Общее время поиска сокращений для 'Никитину': 0.0003 сек
#  Общее время обработки предложения: 0.53 сек
#
# --- Предложение 95 ---
# Текст: Пожня на юго-западе д.Чёрный Наволок (Тамбицы) в 300 м.
# ⏱ Время NLP обработки: 0.5538 сек
# 📍 Топоним: Чёрный Наволок (найден за 0.0000 сек)
#     Поиск топонима 'Чёрный Наволок': 0.0001 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Чёрный Наволок': 0.0007 сек
#     Найдено 1 сокращений за 0.0008 сек
#     Общее время поиска сокращений для 'Чёрный Наволок': 0.0008 сек
#     Найдено сокращение: 'м.' -> 'мыс'
# 📍 Топоним: Тамбицы (найден за 0.0009 сек)
#     Поиск топонима 'Тамбицы': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Тамбицы': 0.0006 сек
#     Найдено 1 сокращений за 0.0006 сек
#     Общее время поиска сокращений для 'Тамбицы': 0.0006 сек
#  Общее время обработки предложения: 0.56 сек
#
# --- Предложение 96 ---
# Текст: Часть деревни ТамбицыЮ расположенная по левому берегу реки Тамбицы в1,3 км выше устья.
# ⏱ Время NLP обработки: 1.0078 сек
# 📍 Топоним: ТамбицыЮ (найден за 0.0000 сек)
#     Поиск топонима 'ТамбицыЮ': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'ТамбицыЮ': 0.0007 сек
#     Сокращения не найдены за 0.0008 сек
#     Общее время поиска сокращений для 'ТамбицыЮ': 0.0008 сек
# 📍 Топоним: Тамбицы (найден за 0.0008 сек)
#     Поиск топонима 'Тамбицы': 0.0000 сек, найдено 2 вхождений
#     Поиск сокращений вокруг 'Тамбицы': 0.0006 сек
#     Поиск сокращений вокруг 'Тамбицы': 0.0006 сек
#     Сокращения не найдены за 0.0012 сек
#     Общее время поиска сокращений для 'Тамбицы': 0.0012 сек
#  Общее время обработки предложения: 1.01 сек
#
# --- Предложение 97 ---
# Текст: Пахотное угодье на юго-восток от деревни в 0,5 км, у дороги в Раньково и Погост.
# ⏱ Время NLP обработки: 1.0515 сек
# 📍 Топоним: Раньково (найден за 0.0000 сек)
#     Поиск топонима 'Раньково': 0.0002 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Раньково': 0.0007 сек
#     Сокращения не найдены за 0.0009 сек
#     Общее время поиска сокращений для 'Раньково': 0.0009 сек
# 📍 Топоним: Погост (найден за 0.0010 сек)
#     Поиск топонима 'Погост': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Погост': 0.0005 сек
#     Сокращения не найдены за 0.0006 сек
#     Общее время поиска сокращений для 'Погост': 0.0006 сек
#  Общее время обработки предложения: 1.05 сек
#
# --- Предложение 98 ---
# Текст: Мост через ручей Niemenoja.
# ⏱ Время NLP обработки: 0.3853 сек
# 📍 Топоним: Niemenoja (найден за 0.0000 сек)
#     Поиск топонима 'Niemenoja': 0.0000 сек, найдено 1 вхождений
#     Поиск сокращений вокруг 'Niemenoja': 0.0003 сек
#     Сокращения не найдены за 0.0004 сек
#     Общее время поиска сокращений для 'Niemenoja': 0.0004 сек
#  Общее время обработки предложения: 0.39 сек
#
# --- Предложение 99 ---
# Текст: Урочище, в котором поля (бывшие пожоги) дер. Перелесок.
# ⏱ Время NLP обработки: 0.6011 сек
#  Время поиска топонимов: 0.0000 сек (не найдено)
#  Общее время обработки предложения: 0.60 сек
#
#  Прогресс: обработано 100/100 предложений
#  Прошло времени: 0:00:56
#  Среднее время поиска сокращений на топоним: 0.0005 сек
#  Среднее время NLP: 0.5641 сек
#  Оставшееся время: ~0:00:00
#
#  ОБРАБОТКА ЗАВЕРШЕНА!
#  Статистика:
#    - Обработано предложений: 100
#    - Найдено топонимов: 147
#    - Найдено сокращений: 46
#    - Общее время: 0:00:56
#
# ⏱ Детализация времени:
#    - Среднее время на предложение: 0.57 сек
#    - Общее время NLP: 0:00:56
#    - Среднее время NLP на предложение: 0.5641 сек
#    - Время создания паттернов: 0.0003 сек
#    - Среднее время поиска сокращений на топоним: 0.0005 сек
#    - Среднее количество топонимов на предложение: 1.47
#    - Среднее количество сокращений на топоним: 0.31
#    - Результаты сохранены в: output.csv
