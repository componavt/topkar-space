# %% [markdown]
# <a href="https://colab.research.google.com/github/componavt/topkar-space/blob/main/src/ner/nltk-ru-ner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NER with NLTK
# Let's use the prepared file with text data from the TopKar project. We will try to extract named entities from the text using the nltk library.
#
# From Named Entity Recognition in nltk, we can get organization, GPE, person as a category.
#
# - Named Entity Recognition (NER)
#     - NLP task to identify important named entities in the text
#         - People, places, organizations
#         - Dates, states, works of art
#     - Can be used alongside topic identification
#     - Who? What? When? Where?

# %%
from pprint import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# > Note: Before using NER through NLTK, you must install 'averaged_perceptron_tagger', 'maxent_ne_chunker', 'words' packages

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import pandas as pd

csv_files = [
#    "https://raw.githubusercontent.com/componavt/topkar-space/main/data/sample10.csv",
    "https://raw.githubusercontent.com/componavt/topkar-space/main/data/sample100.csv",
]

df = pd.concat([pd.read_csv(url, sep = ';') for url in csv_files], ignore_index=True)
df = df.reset_index()  # make sure indexes pair with number of rows
df.head()
# Out:
#    index               Name            Synonym  \
# 0      0  Наволоцкая поляна  наволоцкая поляна
# 1      1    Галайские пожни    галайские пожни
# 2      2          Pahag’ärv           pahagärv
# 3      3        Sod’järvt’e          sodjärvte
# 4      4       Piirdoinkodi       piirdoinkodi
#
#                                                 Text
# 0                Пахотная поляна в устье Пижейручья.
# 1  покосы на юге острова Галайский, см. Галайский...
# 2  Маленькое озерко за хутором Poh'd'ad'g', между...
# 3                  Поляны по дороге в дер. Сидорово.
# 4             Дом в дер. Койвусельга, фам. Михайлов.

# %%
def extract_entity_names(t):
  entity_names = []

  if hasattr(t, 'label') and t.label() == 'NE':
    entity_names.append(' '.join([child[0] for child in t]))
  else:
    for child in t:
      entity_names.extend(extract_entity_names(child))

  return entity_names

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('stopwords')
nltk.download('punkt_tab')# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')          # nltk.ne_chunk_sents

# import string
from nltk.corpus import stopwords
stop_words = stopwords.words("russian")

# !pip install -U pymorphy2==0.9.1
import pymorphy2
morph = pymorphy2.MorphAnalyzer(lang='ru')

# Display
# print("df (toponyms):")
# print(df.head().to_string())
# print(df.describe())

# Convert quotes to list
lines = df['Text'].tolist()
print()
print("Number of toponyms:", len(lines))

#df['Text'] = df['Text'].replace(np.nan, '')
df['Text'] = df['Text'].replace({float('nan'): ""})# replace empty text with "None"

for i, li in enumerate(lines):  #for li in lines:
    print("\n{0}, {1} = ".format(i, li))
    # Tokenize the text line into sentences
    sentences = sent_tokenize(li, language='russian')
    print("\nsentences = ", sentences)
                                                                          # , tagset='universal') universal, wsj, brown
    tokens = [nltk.word_tokenize(sent, language='russian', preserve_line=True)
      for sent in sentences]

    pos_sentences = [nltk.pos_tag(tok) for tok in tokens]

    # Create the named entity chunks: chunked_sentences
    chunked_sentences = nltk.ne_chunk_sents(pos_sentences, binary=False)# binary=False => + GPE, PERSON, ORGANIZATION,

    for sent in chunked_sentences:
      #print("sent = ", sent)
      for chunk in sent:
        #print("chunk = ", chunk)
        if hasattr(chunk, "label"): # and chunk.label() == 'NE':
          print("{0} ({1})".format(chunk, chunk.label()))

#    for sent in sentences:#                                                                universal, wsj, brown
#      tokens = nltk.word_tokenize(sent, language='russian', preserve_line=True)# , tagset='universal')

      # Tag each tokenized sentence into parts of speech: pos_sentences
#      pos_tokens = nltk.pos_tag(tokens)
      #pos_sentences = [nltk.pos_tag(sent) for sent in token_sentences]
#      print("pos_tokens = ", pos_tokens)

#      chunked_tokens = nltk.ne_chunk_sents(pos_tokens, binary=True)# binary=False => + GPE, PERSON, ORGANIZATION,
#      print("chunked_tokens = ", chunked_tokens)

#      for word in tokens:
        # no num and comma
#        if (word.isalpha()) and (not word in stop_words):
#          lemma = morph.parse(word)[0].normal_form
          # print("lemma = ", lemma)

#      for ch_sent in chunked_tokens:
#        for ch in ch_sent:
#          if hasattr(ch, "label") and ch.label() == 'NE':
#            print(ch)
#    if i > 2:
#      break
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# Requirement already satisfied: pymorphy2==0.9.1 in /usr/local/lib/python3.10/dist-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy2==0.9.1) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.10/dist-packages (from pymorphy2==0.9.1) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.10/dist-packages (from pymorphy2==0.9.1) (0.6.2)
#
# Number of toponyms: 100
#
# 0, Пахотная поляна в устье Пижейручья. =
#
# sentences =  ['Пахотная поляна в устье Пижейручья.']
# (PERSON Пахотная/JJ) (PERSON)
#
# 1, покосы на юге острова Галайский, см. Галайский Остров =
#
# sentences =  ['покосы на юге острова Галайский, см. Галайский Остров']
#
# 2, Маленькое озерко за хутором Poh'd'ad'g', между оз. Sar'gär'v и Vougedg'är'v. =
#
# sentences =  ["Маленькое озерко за хутором Poh'd'ad'g', между оз. Sar'gär'v и Vougedg'är'v."]
# (PERSON Маленькое/JJ) (PERSON)
#
# 3, Поляны по дороге в дер. Сидорово. =
#
# sentences =  ['Поляны по дороге в дер. Сидорово.']
# (PERSON Поляны/JJ) (PERSON)
#
# 4, Дом в дер. Койвусельга, фам. Михайлов. =
#
# sentences =  ['Дом в дер. Койвусельга, фам. Михайлов.']
#
# 5, Река Колпь, вытекает из оз. Jokšar'v, течет в Вологодск. обл. =
#
# sentences =  ["Река Колпь, вытекает из оз. Jokšar'v, течет в Вологодск.", 'обл.']
# (GPE Река/NN) (GPE)
# (ORGANIZATION Колпь/NN) (ORGANIZATION)
# (PERSON Jokšar/NNP) (PERSON)
#
# 6, Поле находится в 600-700 м на востоке д.Каскосельга. =
#
# sentences =  ['Поле находится в 600-700 м на востоке д.Каскосельга.']
# (PERSON Поле/JJ) (PERSON)
#
# 7,  =
#
# sentences =  []
#
# 8, Урочище, в котором , по сведениям информатора, в 30-х годах упала сосна. Тут болото. =
#
# sentences =  ['Урочище, в котором , по сведениям информатора, в 30-х годах упала сосна.', 'Тут болото.']
# (GPE Урочище/NN) (GPE)
#
# 9, Покос у мостков через болото ( дер. Slabad). =
#
# sentences =  ['Покос у мостков через болото ( дер. Slabad).']
# (PERSON Покос/JJ) (PERSON)
#
# 10, Гора у оз. Čern'eckiig'är'f, за дер. Селище. =
#
# sentences =  ["Гора у оз. Čern'eckiig'är'f, за дер. Селище."]
# (PERSON Гора/JJ) (PERSON)
#
# 11, Озерко за р. Ивадой, у бол. Levahtso. =
#
# sentences =  ['Озерко за р. Ивадой, у бол. Levahtso.']
# (PERSON Озерко/JJ) (PERSON)
#
# 12, Сельхоз. поляны в Загубье, у тропы в Липовицы. =
#
# sentences =  ['Сельхоз.', 'поляны в Загубье, у тропы в Липовицы.']
# (GPE Сельхоз/NN) (GPE)
#
# 13,  =
#
# sentences =  []
#
# 14, Пожня на с/в от деревни, в направлении Типиниц, вытянута с севера на юг, перед обширным болотом. =
#
# sentences =  ['Пожня на с/в от деревни, в направлении Типиниц, вытянута с севера на юг, перед обширным болотом.']
# (PERSON Пожня/JJ) (PERSON)
#
# 15, Дом в дер. Четчойла. =
#
# sentences =  ['Дом в дер. Четчойла.']
#
# 16, Поляна, расположенная в 1,5 км юго-западнее д.Вороний Остров, "посередине между дорогой (на д.Типиницы) и Онежским озером". =
#
# sentences =  ['Поляна, расположенная в 1,5 км юго-западнее д.Вороний Остров, "посередине между дорогой (на д.Типиницы) и Онежским озером".']
# (GPE Поляна/NN) (GPE)
# (PERSON Остров/NNP) (PERSON)
# (ORGANIZATION Онежским/JJ) (ORGANIZATION)
#
# 17, Поле в 1км на север от д.Вороний Остров. Рядом Малая Избушка. =
#
# sentences =  ['Поле в 1км на север от д.Вороний Остров.', 'Рядом Малая Избушка.']
# (PERSON Рядом/JJ) (PERSON)
# (PERSON Малая/NNP Избушка/NNP) (PERSON)
#
# 18, Покос по ручью Kor'boja. =
#
# sentences =  ["Покос по ручью Kor'boja."]
# (PERSON Покос/JJ) (PERSON)
#
# 19, Болото у оз. Sard'är'f. =
#
# sentences =  ["Болото у оз. Sard'är'f."]
# (PERSON Болото/JJ) (PERSON)
#
# 20, Пожога за урочищем Rustadm'äged. =
#
# sentences =  ["Пожога за урочищем Rustadm'äged."]
# (PERSON Пожога/JJ) (PERSON)
#
# 21, На озере Сарозеро. =
#
# sentences =  ['На озере Сарозеро.']
#
# 22, Ламба в 1,5 км на север от дер. Сеппяваара в сторону дер. Варлов Лес. =
#
# sentences =  ['Ламба в 1,5 км на север от дер. Сеппяваара в сторону дер. Варлов Лес.']
# (PERSON Варлов/NNP Лес/NNP) (PERSON)
#
# 23, Лесное урочище в болота Узкие мошки, в истоках ручья, впадающего в Калейгубу в урочище Уромы. =
#
# sentences =  ['Лесное урочище в болота Узкие мошки, в истоках ручья, впадающего в Калейгубу в урочище Уромы.']
# (PERSON Лесное/JJ) (PERSON)
#
# 24, Поле на одноименном мысу, юго-запад Красного поля д.Сибово. =
#
# sentences =  ['Поле на одноименном мысу, юго-запад Красного поля д.Сибово.']
# (PERSON Поле/JJ) (PERSON)
# (ORGANIZATION Красного/NNP) (ORGANIZATION)
#
# 25, Мыс на южном берегу оз.Кемское, прежде была деревня =
#
# sentences =  ['Мыс на южном берегу оз.Кемское, прежде была деревня']
#
# 26, Ручей в 1,8 км к северо-востоку от д.Сибово. =
#
# sentences =  ['Ручей в 1,8 км к северо-востоку от д.Сибово.']
#
# 27, Один из островов в Красном поле, юго-западнее д.Сибово. =
#
# sentences =  ['Один из островов в Красном поле, юго-западнее д.Сибово.']
# (PERSON Один/JJ) (PERSON)
# (PERSON Красном/NNP) (PERSON)
#
# 28, Покос на р. Большая Сенатка. =
#
# sentences =  ['Покос на р. Большая Сенатка.']
# (PERSON Покос/JJ) (PERSON)
# (PERSON Большая/NNP Сенатка/NNP) (PERSON)
#
# 29, Покос в урочище Šidroja. =
#
# sentences =  ['Покос в урочище Šidroja.']
# (PERSON Покос/JJ) (PERSON)
#
# 30, Ближайший из группы островов на юго-востоке от южной оконечности о.Вигово, в 500 м от берега. =
#
# sentences =  ['Ближайший из группы островов на юго-востоке от южной оконечности о.Вигово, в 500 м от берега.']
# (PERSON Ближайший/JJ) (PERSON)
#
# 31, Болото (дер. Перелесок), примыкающее к оз. Vaagedjär'v. =
#
# sentences =  ["Болото (дер. Перелесок), примыкающее к оз. Vaagedjär'v."]
# (GPE Болото/NN) (GPE)
#
# 32, Покос (дер. Aksintanaz) за урочищем N'ekojain'e. =
#
# sentences =  ["Покос (дер. Aksintanaz) за урочищем N'ekojain'e."]
# (GPE Покос/NN) (GPE)
#
# 33, Поле (дер. Aksintanaz). =
#
# sentences =  ['Поле (дер. Aksintanaz).']
# (GPE Поле/NN) (GPE)
#
# 34, Покосы. =
#
# sentences =  ['Покосы.']
# (GPE Покосы/NN) (GPE)
#
# 35, Река, вытекающая из оз. Яндомозеро в южной его части, протекающая на юго-восток и впадающая в Онежское озеро, в губу с восточной стороны д. Усть-Яндома. =
#
# sentences =  ['Река, вытекающая из оз. Яндомозеро в южной его части, протекающая на юго-восток и впадающая в Онежское озеро, в губу с восточной стороны д. Усть-Яндома.']
# (GPE Река/NN) (GPE)
#
# 36, Озеро (басс. р. Иводы), в 2 км. от дер. Пустошка. =
#
# sentences =  ['Озеро (басс. р. Иводы), в 2 км.', 'от дер. Пустошка.']
# (GPE Озеро/NN) (GPE)
#
# 37, Ламба в 2,3 км на с/з от дер. Сеппяваара в сторону дер. Воронова Сельга. =
#
# sentences =  ['Ламба в 2,3 км на с/з от дер. Сеппяваара в сторону дер. Воронова Сельга.']
#
# 38,  =
#
# sentences =  []
#
# 39, Покос (дер. Панкратово) на берегу оз. Sepad'är'v. =
#
# sentences =  ["Покос (дер. Панкратово) на берегу оз. Sepad'är'v."]
# (GPE Покос/NN) (GPE)
#
# 40, Ручей, течет из оз. Sagažg'är'v в оз. S'epatg'är, название связывают  с тем, что "oja astub korbedm'e, pimedas sijas". =
#
# sentences =  ['Ручей, течет из оз. Sagažg\'är\'v в оз. S\'epatg\'är, название связывают  с тем, что "oja astub korbedm\'e, pimedas sijas".']
# (GPE Ручей/NN) (GPE)
#
# 41,  Поляна из группы полян, расположенных в 100 м от южной оконечности д. Саньки. =
#
# sentences =  [' Поляна из группы полян, расположенных в 100 м от южной оконечности д. Саньки.']
# (PERSON Поляна/JJ) (PERSON)
#
# 42, Часть оз. Нинисельгское, где купались. =
#
# sentences =  ['Часть оз. Нинисельгское, где купались.']
# (PERSON Часть/JJ) (PERSON)
#
# 43,  Полянка на западе д. Углевщина. =
#
# sentences =  [' Полянка на западе д. Углевщина.']
# (PERSON Полянка/JJ) (PERSON)
#
# 44, Деревня (бывшая) на с/в от Типиниц, на высоком месте. =
#
# sentences =  ['Деревня (бывшая) на с/в от Типиниц, на высоком месте.']
# (GPE Деревня/NN) (GPE)
#
# 45, Болото по направлению к дер. Бор, по сведениям информатора "Mat'er'eiso". =
#
# sentences =  ['Болото по направлению к дер. Бор, по сведениям информатора "Mat\'er\'eiso".']
# (PERSON Болото/JJ) (PERSON)
#
# 46, Пахотная поляна на северной окраине деревни, у ручья, впадающего в Онежское озеро. =
#
# sentences =  ['Пахотная поляна на северной окраине деревни, у ручья, впадающего в Онежское озеро.']
# (PERSON Пахотная/JJ) (PERSON)
#
# 47, Луда на Яндомозере у Карельских островов. =
#
# sentences =  ['Луда на Яндомозере у Карельских островов.']
# (PERSON Луда/JJ) (PERSON)
#
# 48, Бывший пожог в урочище Kalaidai. =
#
# sentences =  ['Бывший пожог в урочище Kalaidai.']
# (PERSON Бывший/JJ) (PERSON)
#
# 49, см. Корбозеро =
#
# sentences =  ['см. Корбозеро']
#
# 50, Бывший хутор у дер. Laht (Лахта). =
#
# sentences =  ['Бывший хутор у дер. Laht (Лахта).']
# (PERSON Бывший/JJ) (PERSON)
#
# 51,  Покос на Яндомозере, см. Виднаволок - мыс. =
#
# sentences =  [' Покос на Яндомозере, см. Виднаволок - мыс.']
# (PERSON Покос/JJ) (PERSON)
#
# 52, Пахотная поляна в лесу, у дороги на Корбозеро. =
#
# sentences =  ['Пахотная поляна в лесу, у дороги на Корбозеро.']
# (PERSON Пахотная/JJ) (PERSON)
#
# 53, Часть пруда Luhtu, по хозяину дома. =
#
# sentences =  ['Часть пруда Luhtu, по хозяину дома.']
# (PERSON Часть/JJ) (PERSON)
#
# 54, Остров на озере Sar'jar'v. =
#
# sentences =  ["Остров на озере Sar'jar'v."]
# (PERSON Остров/JJ) (PERSON)
#
# 55, Поле в дер. Тигвера рядом с местом слияния рек Тигверки и Тулосозера. =
#
# sentences =  ['Поле в дер. Тигвера рядом с местом слияния рек Тигверки и Тулосозера.']
# (PERSON Поле/JJ) (PERSON)
# (PERSON Тигвера/NNP) (PERSON)
#
# 56, Мост через реку Тигверку. =
#
# sentences =  ['Мост через реку Тигверку.']
# (PERSON Мост/JJ) (PERSON)
#
# 57, Урочище вокруг моста. =
#
# sentences =  ['Урочище вокруг моста.']
# (PERSON Урочище/JJ) (PERSON)
#
# 58, С/х угодье (поляны), бывшие подсеки, в лесу. =
#
# sentences =  ['С/х угодье (поляны), бывшие подсеки, в лесу.']
#
# 59, Озеро по направлению к Пелушам, в стороне от дороги. =
#
# sentences =  ['Озеро по направлению к Пелушам, в стороне от дороги.']
# (PERSON Озеро/JJ) (PERSON)
#
# 60, Пахотная поляна к северу от деревни, у Лельреки. =
#
# sentences =  ['Пахотная поляна к северу от деревни, у Лельреки.']
# (PERSON Пахотная/JJ) (PERSON)
#
# 61, Поле к северу от Педейнаволока, на берегу залива Великая Губа. =
#
# sentences =  ['Поле к северу от Педейнаволока, на берегу залива Великая Губа.']
# (PERSON Поле/JJ) (PERSON)
# (PERSON Великая/NNP Губа/NNP) (PERSON)
#
# 62, Бывшая деревня Подовинники. =
#
# sentences =  ['Бывшая деревня Подовинники.']
# (PERSON Бывшая/JJ) (PERSON)
#
# 63, Исток ручья Šoudoja. =
#
# sentences =  ['Исток ручья Šoudoja.']
# (PERSON Исток/JJ) (PERSON)
#
# 64, Болото в 2 км. от дер., в истоках ручья Mel'n'icojain'e. =
#
# sentences =  ['Болото в 2 км.', "от дер., в истоках ручья Mel'n'icojain'e."]
# (GPE Болото/JJ) (GPE)
#
# 65, Деревня за дер. Нойдала. =
#
# sentences =  ['Деревня за дер. Нойдала.']
# (PERSON Деревня/JJ) (PERSON)
#
# 66, Поляна к с/в от д.Поля в 1,5 км, на высоком месте. =
#
# sentences =  ['Поляна к с/в от д.Поля в 1,5 км, на высоком месте.']
# (PERSON Поляна/JJ) (PERSON)
#
# 67, Покос на р. Šalg'ögi, при впадении ручья Rihoja, выше моста Lava. =
#
# sentences =  ["Покос на р. Šalg'ögi, при впадении ручья Rihoja, выше моста Lava."]
# (PERSON Покос/JJ) (PERSON)
#
# 68, Бывшая деревня у Лахты. =
#
# sentences =  ['Бывшая деревня у Лахты.']
# (PERSON Бывшая/JJ) (PERSON)
#
# 69, Место на западном берегу Яндомозера, куда приставали на лодках едущие из Марковщины в Великую Губу. =
#
# sentences =  ['Место на западном берегу Яндомозера, куда приставали на лодках едущие из Марковщины в Великую Губу.']
# (PERSON Место/JJ) (PERSON)
# (PERSON Великую/NNP Губу/NNP) (PERSON)
#
# 70, Покос на берегу Виговской губы, между Педейнаволоком и устьем Лейреки. =
#
# sentences =  ['Покос на берегу Виговской губы, между Педейнаволоком и устьем Лейреки.']
# (PERSON Покос/JJ) (PERSON)
#
# 71,  =
#
# sentences =  []
#
# 72,  =
#
# sentences =  []
#
# 73, Болотистый сенокос к западу от урочища Кумбыша, у Ушового моста. С севера к нему примыкает Северница и Безрукий Обод. =
#
# sentences =  ['Болотистый сенокос к западу от урочища Кумбыша, у Ушового моста.', 'С севера к нему примыкает Северница и Безрукий Обод.']
# (PERSON Болотистый/JJ) (PERSON)
# (PERSON Ушового/NNP) (PERSON)
#
# 74, Озеро по Пустынской дороге в направлении Сяргозера. =
#
# sentences =  ['Озеро по Пустынской дороге в направлении Сяргозера.']
# (PERSON Озеро/JJ) (PERSON)
#
# 75, Река, впадает в р. Шолу, ниже р. Сепатки. =
#
# sentences =  ['Река, впадает в р. Шолу, ниже р. Сепатки.']
# (GPE Река/NN) (GPE)
#
# 76, Местность в дер. Сидорово. =
#
# sentences =  ['Местность в дер. Сидорово.']
# (PERSON Местность/JJ) (PERSON)
#
# 77,  Покос, 1,5 км к востоку от д. Усть-Яндома, по дороге в Типиницы, перед Глубоким Ручьем. =
#
# sentences =  [' Покос, 1,5 км к востоку от д. Усть-Яндома, по дороге в Типиницы, перед Глубоким Ручьем.']
# (GPE Покос/NN) (GPE)
#
# 78,  =
#
# sentences =  []
#
# 79, Урочище (лесное), где росли грибы (дер. Сташково Радогощенский с/с). =
#
# sentences =  ['Урочище (лесное), где росли грибы (дер. Сташково Радогощенский с/с).']
# (GPE Урочище/NN) (GPE)
#
# 80,  =
#
# sentences =  []
#
# 81, Бывшая деревня на водоразделе, на высоком месте. =
#
# sentences =  ['Бывшая деревня на водоразделе, на высоком месте.']
# (PERSON Бывшая/JJ) (PERSON)
#
# 82, Горка у озера в деревне на месте нового колодца. =
#
# sentences =  ['Горка у озера в деревне на месте нового колодца.']
# (PERSON Горка/JJ) (PERSON)
#
# 83, Поле на мысу, вдающемсяс юга в болото напротив д. Задняя. =
#
# sentences =  ['Поле на мысу, вдающемсяс юга в болото напротив д. Задняя.']
# (PERSON Поле/JJ) (PERSON)
#
# 84, Пожня =
#
# sentences =  ['Пожня']
# (GPE Пожня/NN) (GPE)
#
# 85, Ручей, течет из оз. Lidnag'är'v. =
#
# sentences =  ["Ручей, течет из оз. Lidnag'är'v."]
# (GPE Ручей/NN) (GPE)
#
# 86, Мыс, расположенный в 0,5 км на север от о.Вороний. =
#
# sentences =  ['Мыс, расположенный в 0,5 км на север от о.Вороний.']
# (GPE Мыс/NN) (GPE)
#
# 87, Место рыбной ловли в Великой губе, 1,5 км на запад от д.Вигово. =
#
# sentences =  ['Место рыбной ловли в Великой губе, 1,5 км на запад от д.Вигово.']
# (PERSON Место/JJ) (PERSON)
# (PERSON Великой/NNP) (PERSON)
#
# 88,  Покосы, 2 км на север от Марковщины, по дороге в Мягкую Сельгу (Космозерский с/с), у болотины, через которую сделаны мостки. =
#
# sentences =  [' Покосы, 2 км на север от Марковщины, по дороге в Мягкую Сельгу (Космозерский с/с), у болотины, через которую сделаны мостки.']
# (GPE Покосы/NN) (GPE)
# (PERSON Мягкую/NNP Сельгу/NNP) (PERSON)
# (ORGANIZATION Космозерский/NNP) (ORGANIZATION)
#
# 89, Озеро (ламба) в деревне. =
#
# sentences =  ['Озеро (ламба) в деревне.']
# (GPE Озеро/NN) (GPE)
#
# 90, покос, 0.5 км на юго-запад от д. Истомино, на мысу Саньковский Наволок =
#
# sentences =  ['покос, 0.5 км на юго-запад от д. Истомино, на мысу Саньковский Наволок']
#
# 91, Озеро в 3 верстах от дер (басс. р Колпь). =
#
# sentences =  ['Озеро в 3 верстах от дер (басс. р Колпь).']
#
# 92, Болото в 0, 5 км на с/в от дер. Четчойла =
#
# sentences =  ['Болото в 0, 5 км на с/в от дер. Четчойла']
# (GPE Болото/JJ) (GPE)
#
# 93, Пожня =
#
# sentences =  ['Пожня']
# (GPE Пожня/NN) (GPE)
#
# 94, Река, находится в 300 м от д.Типиницы на запад.Вытекает из болота у д. Холмы, впадает в Типиницкий залив. =
#
# sentences =  ['Река, находится в 300 м от д.Типиницы на запад.Вытекает из болота у д. Холмы, впадает в Типиницкий залив.']
# (GPE Река/NN) (GPE)
#
# 95,  =
#
# sentences =  []
#
# 96, Болото в 3 км. от дер. Turžin. =
#
# sentences =  ['Болото в 3 км.', 'от дер. Turžin.']
# (GPE Болото/JJ) (GPE)
#
# 97, Центральная часть д.Типиницы, на горке =
#
# sentences =  ['Центральная часть д.Типиницы, на горке']
#
# 98,  =
#
# sentences =  []
#
# 99, Пахотная полоса. =
#
# sentences =  ['Пахотная полоса.']
# (GPE Пахотная/JJ) (GPE)
